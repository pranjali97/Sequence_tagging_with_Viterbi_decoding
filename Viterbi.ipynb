# %%
import pandas as pd
import math
import os
import nltk
from sklearn import metrics
from collections import Counter

# %%
## Module to load training, dev and test data
def get_token_tag_tuples(sent):
    return([nltk.tag.str2tuple(t) for t in sent.split()])

def get_tagged_sentences(text):
    sentences = []
    blocks = text.split("======================================")
    for block in blocks:
        sents = block.split("\n\n")
        for sent in sents:
            sent = sent.replace("\n", "").replace("[", "").replace("]", "")
            if sent is not "":
                sentences.append(sent)
    return sentences

def load_treebank_splits(datadir):
    train = []
    dev = []
    test = []
    print("Loading treebank data...")
    for subdir, dirs, files in os.walk(datadir):
        for filename in files:
            if filename.endswith(".pos"):
                if subdir.split(os.sep)[-1].startswith('.'):
                    pass
                else:
                    filepath = subdir + os.sep + filename
                    # print(filepath)
                    with open(filepath, "r") as fh:
                        text = fh.read()
                        if int(subdir.split(os.sep)[-1]) in range(0,19):
                            train += get_tagged_sentences(text)
                        if int(subdir.split(os.sep)[-1]) in range(19, 22):
                            dev += get_tagged_sentences(text)
                        if int(subdir.split(os.sep)[-1]) in range(22, 25):
                            test += get_tagged_sentences(text)
    print("Train set size: ", len(train))
    print("Dev set size: ", len(dev))
    print("Test set size: ", len(test))
    return train, dev, test
# Out:
# <>:11: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:11: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /tmp/ipykernel_20546/2881052629.py:11: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if sent is not "":

# %%
datadir = 'data/penn-treeban3-wsj/wsj'
train, dev, test = load_treebank_splits(datadir)
# Out:
# Loading treebank data...
# Train set size:  51681
# Dev set size:  7863
# Test set size:  9046

# %%
## Tokenize data and add <START> and <STOP> tags
def tokenize_data(data):
    processed_data = []
    for sentence in data:
        temp = []
        temp.append(('<START>', '<START>'))
        processed_sent = get_token_tag_tuples(sentence)
        temp.extend(processed_sent)
        temp.append(('<STOP>', '<STOP>'))
        processed_data.append(temp)
    return processed_data

def flatten_pairs(data):
    return [tup for sent in data for tup in sent]

# %%
train_pairs = tokenize_data(train)
dev_pairs = tokenize_data(dev)
test_pairs = tokenize_data(test)

# %%
print('Train set: ', len(train_pairs))
print('Dev set: ', len(dev_pairs))
print('Test set: ', len(test_pairs))
# Out:
# Train set:  51681
# Dev set:  7863
# Test set:  9046

# %%
train_pairs_flat = flatten_pairs(train_pairs)
dev_pairs_flat = flatten_pairs(dev_pairs)
test_pairs_flat = flatten_pairs(test_pairs)

# %%
print(len(train_pairs_flat))
print(len(dev_pairs_flat))
print(len(test_pairs_flat))
# Out:
# 1073238
# 163883
# 189230

# %%
# Create train token and tag vocab

# %%
# Create tokena and tag vocabulary for training data
train_tokens = [tag[0] for tag in train_pairs_flat]
train_tags = [tag[1] for tag in train_pairs_flat]

train_vocab = set(train_tokens)
train_tag_vocab = set(train_tags)

print('Train vocabulary:', len(train_vocab))
print('Train tag vocabulary:', len(train_tag_vocab))
# Out:
# Train vocabulary: 44547
# Train tag vocabulary: 79

# %%
## Create useful counter dictionaries
def get_train_freq_dict(train_pairs, train_tags):
    word_tag_bigrams = []
    tags_bigram = []
    for sent in train_pairs:
        word_tag_bigrams.extend(sent)
        sent_tags = [tup[1] for tup in sent]
        tags_bigram.extend([(s1, s2) for s1, s2 in zip(sent_tags, sent_tags[1:])])
    tags_counter = Counter(train_tags)
    tags_bigram_counter = Counter(tags_bigram)
    word_tag_bigram_counter = Counter(word_tag_bigrams)
    return word_tag_bigram_counter, tags_bigram_counter, tags_counter

# %%
word_tag_bigram_counter, tags_bigram_counter, tags_counter = get_train_freq_dict(train_pairs, train_tags)

# %%
## Transition and emission probabilities
def get_transition_prob(t_prev, t, alpha):
    v = len(train_vocab)
    prob = (tags_bigram_counter[(t_prev, t)]+ alpha)/(tags_counter[t_prev] + v*alpha)
    return prob

def get_emission_prob(w, t, alpha):
    v = len(train_vocab)
    prob = (word_tag_bigram_counter[(w,t)] + alpha)/(tags_counter[t] + v*alpha)
    return prob

# %%
# Viterbi ALgorithm

import numpy as np
from tqdm import tqdm

def evaluate(test_sentences, predictions):
    gold = [str(tag) for sentence in test_sentences for token, tag in sentence]
    pred = [tag for sentence in predictions for tag in sentence]
    print(metrics.confusion_matrix(gold, pred))
    print(metrics.classification_report(gold, pred))

def viterbi(data_pair, train_tag_vocab, alpha):
    all_sequences = []
    train_tag_vocab = list(train_tag_vocab)
    predictions = []
    for sent in tqdm(data_pair):
        v_matrix = np.zeros((len(train_tag_vocab), len(sent)-1))
        for key, token in enumerate(sent[1:]):
            for i, possible_tag in enumerate(train_tag_vocab):
                if key == 0:
                    previous_tag = '<START>'
                    log_t_prob = math.log(get_transition_prob(previous_tag, possible_tag, alpha),2)
                    log_e_prob = math.log(get_emission_prob(token[0], possible_tag, alpha), 2)
                    joint_prob = log_t_prob + log_e_prob

                    v_matrix[i][key] =  joint_prob
                else:
                    state = []
                    for j, prev_tag in enumerate(train_tag_vocab):
                        log_t_prob = math.log(get_transition_prob(prev_tag, possible_tag, alpha),2)
                        log_e_prob = math.log(get_emission_prob(token[0], possible_tag, alpha), 2)
                        v_prev = v_matrix[j][key-1]
                        joint_prob = log_t_prob + log_e_prob + v_prev
                        state.append((prev_tag, joint_prob))
                    max_prob = max([tup[1] for tup in state])
                    max_state = [tup for tup in state if tup[1] == max_prob][0][0]
                    if not isinstance(max_prob, float):
                        # print(max_prob)
                        raise Exception
                    v_matrix[i][key] = max_prob
        # backtrack to get tag seq
        temp_df = pd.DataFrame(v_matrix, columns = range(len(sent)-1))
        seq = []
        for token in reversed(range(0, len(sent)-1)):
            loc = temp_df[token].idxmax()
            seq.append(train_tag_vocab[loc])
        seq = seq[::-1]
        all_sequences.append(seq)
    return all_sequences

# %%
alpha_list = [0.2, 0.1, 0.01, 0.001, 1]
for alpha in alpha_list:
    print('Alpha value: ', alpha)
    seq = viterbi(dev_pairs, train_tag_vocab, alpha)
    new_seq = []
    for sent in seq:
        n_seq = []
        n_seq.append('<START>')
        n_seq.extend(sent)
        new_seq.append(n_seq)
    evaluate(dev_pairs, new_seq)
# Out:
# Alpha value:  0.2
# 100% 7863/7863 [17:44<00:00,  7.38it/s]
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            #       1.00      1.00      1.00        31
#            $       0.98      1.00      0.99      1248
#           ''       0.83      1.00      0.91      1168
#            (       1.00      1.00      1.00       244
#            )       1.00      1.00      1.00       244
#            ,       1.00      1.00      1.00      7931
#            .       1.00      1.00      1.00      6125
#            :       0.99      0.99      0.99       775
#      <START>       1.00      1.00      1.00      7863
#       <STOP>       0.99      1.00      0.99      7863
#           CC       0.99      1.00      0.99      3777
#           CD       0.97      0.94      0.95      5766
#           DT       0.95      0.99      0.97     12639
#           EX       0.91      0.62      0.74       133
#           FW       0.00      0.00      0.00        25
#           IN       0.95      0.98      0.97     15497
#        IN|RB       0.00      0.00      0.00         1
#           JJ       0.87      0.84      0.86      9014
#          JJR       0.74      0.87      0.80       506
#          JJS       0.85      0.94      0.90       303
#           LS       0.00      0.00      0.00         2
#           MD       0.99      0.99      0.99      1455
#           NN       0.94      0.92      0.93     20734
#          NNP       0.92      0.90      0.91     14989
#         NNPS       0.77      0.14      0.24       470
#          NNS       0.95      0.93      0.94      9089
#       NNS|NN       0.00      0.00      0.00         1
#     NNS|NNPS       0.00      0.00      0.00         1
#        NN|JJ       0.00      0.00      0.00         2
#       NN|NNS       0.00      0.00      0.00         1
#          PDT       0.00      0.00      0.00        72
#          POS       0.99      0.99      0.99      1412
#          PRP       0.94      0.99      0.97      2673
#         PRP$       0.99      1.00      1.00      1317
#           RB       0.90      0.85      0.87      4789
#          RBR       0.59      0.30      0.39       240
#      RBR|JJR       0.00      0.00      0.00         1
#          RBS       0.33      0.04      0.07        52
#      RBS|JJS       0.00      0.00      0.00         1
#        RB|RP       0.00      0.00      0.00         2
#           RP       0.37      0.23      0.28       203
#          SYM       1.00      0.75      0.86         4
#           TO       0.97      1.00      0.99      3441
#           UH       0.00      0.00      0.00        16
#           VB       0.86      0.94      0.90      3948
#          VBD       0.92      0.93      0.92      5198
#      VBD|VBN       0.00      0.00      0.00         1
#          VBG       0.94      0.85      0.89      2204
#       VBG|JJ       0.00      0.00      0.00         1
#       VBG|NN       0.00      0.00      0.00         4
#          VBN       0.78      0.80      0.79      3143
#       VBN|JJ       0.00      0.00      0.00         1
#      VBN|VBD       0.00      0.00      0.00         1
#          VBP       0.80      0.87      0.83      1678
#          VBZ       0.96      0.95      0.95      3118
#          WDT       0.94      0.97      0.96       606
#           WP       0.99      1.00      1.00       354
#          WP$       1.00      0.95      0.97        19
#          WRB       1.00      0.99      1.00       310
#           ``       0.70      1.00      0.82      1177
#
#     accuracy                           0.94    163883
#    macro avg       0.64      0.62      0.63    163883
# weighted avg       0.94      0.94      0.94    163883
#
# Alpha value:  0.1
# 100% 7863/7863 [17:39<00:00,  7.42it/s]
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            #       1.00      1.00      1.00        31
#            $       0.98      1.00      0.99      1248
#           ''       0.85      1.00      0.92      1168
#            (       1.00      1.00      1.00       244
#            )       1.00      1.00      1.00       244
#            ,       1.00      1.00      1.00      7931
#            .       0.97      1.00      0.99      6125
#            :       0.99      0.99      0.99       775
#      <START>       1.00      1.00      1.00      7863
#       <STOP>       0.99      1.00      1.00      7863
#           CC       0.99      1.00      0.99      3777
#           CD       0.96      0.95      0.95      5766
#           DT       0.95      0.99      0.97     12639
#           EX       0.92      0.77      0.84       133
#           FW       0.00      0.00      0.00        25
#           IN       0.97      0.98      0.97     15497
#        IN|RB       0.00      0.00      0.00         1
#           JJ       0.88      0.85      0.86      9014
#          JJR       0.74      0.89      0.81       506
#          JJS       0.67      0.94      0.79       303
#           LS       0.00      0.00      0.00         2
#           MD       0.99      0.99      0.99      1455
#           NN       0.95      0.92      0.93     20734
#          NNP       0.94      0.85      0.89     14989
#         NNPS       0.74      0.25      0.37       470
#          NNS       0.96      0.94      0.95      9089
#       NNS|NN       0.00      0.00      0.00         1
#     NNS|NNPS       0.00      0.00      0.00         1
#        NN|JJ       0.00      0.00      0.00         2
#       NN|NNS       0.00      0.00      0.00         1
#          PDT       0.00      0.00      0.00        72
#          POS       0.62      0.99      0.76      1412
#          PRP       0.86      0.99      0.92      2673
#         PRP$       0.99      1.00      1.00      1317
#           RB       0.90      0.85      0.88      4789
#          RBR       0.59      0.33      0.42       240
#      RBR|JJR       0.00      0.00      0.00         1
#          RBS       0.33      0.04      0.07        52
#      RBS|JJS       0.00      0.00      0.00         1
#        RB|RP       0.00      0.00      0.00         2
#           RP       0.38      0.38      0.38       203
#          SYM       1.00      1.00      1.00         4
#           TO       0.97      1.00      0.99      3441
#           UH       0.00      0.00      0.00        16
#           VB       0.87      0.94      0.91      3948
#          VBD       0.92      0.93      0.92      5198
#      VBD|VBN       0.00      0.00      0.00         1
#          VBG       0.93      0.86      0.89      2204
#       VBG|JJ       0.00      0.00      0.00         1
#       VBG|NN       0.00      0.00      0.00         4
#          VBN       0.79      0.80      0.80      3143
#       VBN|JJ       0.00      0.00      0.00         1
#      VBN|VBD       0.00      0.00      0.00         1
#          VBP       0.85      0.88      0.87      1678
#          VBZ       0.96      0.95      0.95      3118
#          WDT       0.94      0.97      0.95       606
#           WP       0.99      1.00      1.00       354
#          WP$       1.00      0.95      0.97        19
#          WRB       1.00      0.99      1.00       310
#           ``       0.73      1.00      0.84      1177
#
#     accuracy                           0.94    163883
#    macro avg       0.63      0.64      0.63    163883
# weighted avg       0.94      0.94      0.94    163883
#
# Alpha value:  0.01
# 100% 7863/7863 [17:38<00:00,  7.43it/s]
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            #       1.00      1.00      1.00        31
#            $       0.99      1.00      0.99      1248
#           ''       0.86      1.00      0.92      1168
#            (       1.00      1.00      1.00       244
#            )       1.00      1.00      1.00       244
#            ,       1.00      1.00      1.00      7931
#            .       0.98      1.00      0.99      6125
#            :       0.99      0.99      0.99       775
#      <START>       1.00      1.00      1.00      7863
#       <STOP>       1.00      1.00      1.00      7863
#           CC       0.99      1.00      0.99      3777
#           CD       0.97      0.95      0.96      5766
#           DT       0.99      0.99      0.99     12639
#           EX       0.40      0.85      0.54       133
#           FW       0.07      0.44      0.11        25
#           IN       0.97      0.98      0.97     15497
#        IN|RB       0.00      0.00      0.00         1
#           JJ       0.88      0.85      0.86      9014
#          JJR       0.57      0.89      0.69       506
#          JJS       0.25      0.93      0.39       303
#           LS       0.00      0.00      0.00         2
#           MD       0.98      1.00      0.99      1455
#           NN       0.97      0.91      0.94     20734
#          NNP       0.95      0.84      0.89     14989
#         NNPS       0.69      0.62      0.65       470
#          NNS       0.96      0.94      0.95      9089
#       NNS|NN       0.00      0.00      0.00         1
#     NNS|NNPS       0.00      0.00      0.00         1
#        NN|JJ       0.00      0.00      0.00         2
#       NN|NNS       0.00      0.00      0.00         1
#          PDT       0.17      0.01      0.03        72
#          POS       0.62      0.98      0.76      1412
#          PRP       0.99      0.99      0.99      2673
#         PRP$       0.70      1.00      0.82      1317
#           RB       0.92      0.84      0.88      4789
#          RBR       0.57      0.41      0.48       240
#      RBR|JJR       0.00      0.00      0.00         1
#          RBS       0.29      0.15      0.20        52
#      RBS|JJS       0.00      0.00      0.00         1
#        RB|RP       0.00      0.00      0.00         2
#           RP       0.23      0.66      0.34       203
#          SYM       1.00      1.00      1.00         4
#           TO       1.00      1.00      1.00      3441
#           UH       0.50      0.12      0.20        16
#           VB       0.91      0.94      0.92      3948
#          VBD       0.92      0.93      0.92      5198
#      VBD|VBN       0.00      0.00      0.00         1
#          VBG       0.92      0.87      0.90      2204
#       VBG|JJ       0.00      0.00      0.00         1
#       VBG|NN       0.00      0.00      0.00         4
#          VBN       0.78      0.81      0.79      3143
#       VBN|JJ       0.00      0.00      0.00         1
#      VBN|VBD       0.00      0.00      0.00         1
#          VBP       0.86      0.88      0.87      1678
#          VBZ       0.96      0.95      0.96      3118
#          WDT       0.58      0.97      0.73       606
#           WP       0.99      1.00      1.00       354
#          WP$       1.00      0.95      0.97        19
#          WRB       1.00      0.99      1.00       310
#           ``       0.98      1.00      0.99      1177
#
#     accuracy                           0.94    163883
#    macro avg       0.62      0.66      0.63    163883
# weighted avg       0.95      0.94      0.94    163883
#
# Alpha value:  0.001
# 100% 7863/7863 [17:42<00:00,  7.40it/s]
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            #       1.00      1.00      1.00        31
#            $       1.00      1.00      1.00      1248
#           ''       1.00      1.00      1.00      1168
#            (       0.95      1.00      0.97       244
#            )       0.66      1.00      0.79       244
#            ,       1.00      1.00      1.00      7931
#            .       0.98      1.00      0.99      6125
#            :       0.99      0.99      0.99       775
#      <START>       1.00      1.00      1.00      7863
#       <STOP>       1.00      1.00      1.00      7863
#           CC       0.99      1.00      0.99      3777
#           CD       0.99      0.95      0.97      5766
#           DT       0.99      0.99      0.99     12639
#           EX       0.30      0.97      0.46       133
#           FW       0.05      0.56      0.09        25
#           IN       0.97      0.97      0.97     15497
#        IN|RB       0.00      0.00      0.00         1
#           JJ       0.88      0.85      0.86      9014
#          JJR       0.75      0.88      0.81       506
#          JJS       0.60      0.86      0.71       303
#        JJ|NN       0.00      0.00      0.00         0
#           LS       0.00      0.00      0.00         2
#           MD       0.99      1.00      0.99      1455
#           NN       0.97      0.91      0.94     20734
#          NNP       0.95      0.84      0.89     14989
#         NNPS       0.69      0.63      0.66       470
#          NNS       0.96      0.94      0.95      9089
#       NNS|NN       0.00      0.00      0.00         1
#     NNS|NNPS       0.00      0.00      0.00         1
#        NN|JJ       0.00      0.00      0.00         2
#       NN|NNS       0.00      0.00      0.00         1
#          PDT       0.38      0.12      0.19        72
#          POS       0.62      0.98      0.76      1412
#          PRP       0.99      0.99      0.99      2673
#         PRP$       0.70      1.00      0.82      1317
#           RB       0.92      0.84      0.88      4789
#          RBR       0.37      0.43      0.40       240
#      RBR|JJR       0.00      0.00      0.00         1
#          RBS       0.06      0.77      0.10        52
#      RBS|JJS       0.00      0.00      0.00         1
#        RB|RP       0.00      0.00      0.00         2
#           RP       0.21      0.68      0.32       203
#          SYM       0.01      1.00      0.02         4
#           TO       1.00      1.00      1.00      3441
#           UH       0.12      0.25      0.16        16
#           VB       0.91      0.93      0.92      3948
#          VBD       0.92      0.93      0.92      5198
#      VBD|VBN       0.00      0.00      0.00         1
#          VBG       0.92      0.87      0.90      2204
#       VBG|JJ       0.00      0.00      0.00         1
#       VBG|NN       0.00      0.00      0.00         4
#          VBN       0.82      0.80      0.81      3143
#       VBN|JJ       0.00      0.00      0.00         1
#      VBN|VBD       0.00      0.00      0.00         1
#          VBP       0.87      0.88      0.88      1678
#          VBZ       0.96      0.95      0.96      3118
#          WDT       0.93      0.97      0.95       606
#           WP       0.99      1.00      1.00       354
#          WP$       0.09      1.00      0.16        19
#          WRB       1.00      0.99      1.00       310
#           ``       1.00      1.00      1.00      1177
#
#     accuracy                           0.94    163883
#    macro avg       0.58      0.67      0.59    163883
# weighted avg       0.95      0.94      0.94    163883
#
# Alpha value:  1
# 100% 7863/7863 [17:14<00:00,  7.60it/s]
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            #       0.00      0.00      0.00        31
#            $       0.98      1.00      0.99      1248
#           ''       1.00      1.00      1.00      1168
#            (       1.00      0.94      0.97       244
#            )       1.00      0.99      1.00       244
#            ,       1.00      1.00      1.00      7931
#            .       1.00      1.00      1.00      6125
#            :       1.00      0.99      1.00       775
#      <START>       1.00      1.00      1.00      7863
#       <STOP>       0.98      1.00      0.99      7863
#           CC       0.93      0.99      0.96      3777
#           CD       0.96      0.91      0.94      5766
#           DT       0.86      0.99      0.92     12639
#           EX       0.94      0.35      0.51       133
#           FW       0.00      0.00      0.00        25
#           IN       0.90      0.99      0.94     15497
#        IN|RB       0.00      0.00      0.00         1
#           JJ       0.88      0.81      0.84      9014
#          JJR       0.73      0.77      0.75       506
#          JJS       0.84      0.88      0.86       303
#           LS       0.00      0.00      0.00         2
#           MD       1.00      0.99      0.99      1455
#           NN       0.90      0.92      0.91     20734
#          NNP       0.91      0.88      0.90     14989
#         NNPS       1.00      0.02      0.04       470
#          NNS       0.98      0.90      0.94      9089
#       NNS|NN       0.00      0.00      0.00         1
#     NNS|NNPS       0.00      0.00      0.00         1
#        NN|JJ       0.00      0.00      0.00         2
#       NN|NNS       0.00      0.00      0.00         1
#          PDT       0.00      0.00      0.00        72
#          POS       0.98      1.00      0.99      1412
#          PRP       0.92      0.99      0.95      2673
#         PRP$       0.99      1.00      1.00      1317
#           RB       0.88      0.82      0.85      4789
#          RBR       0.58      0.07      0.13       240
#      RBR|JJR       0.00      0.00      0.00         1
#          RBS       0.67      0.04      0.07        52
#      RBS|JJS       0.00      0.00      0.00         1
#        RB|RP       0.00      0.00      0.00         2
#           RP       0.00      0.00      0.00       203
#          SYM       0.00      0.00      0.00         4
#           TO       1.00      1.00      1.00      3441
#           UH       0.00      0.00      0.00        16
#           VB       0.85      0.93      0.89      3948
#          VBD       0.90      0.93      0.92      5198
#      VBD|VBN       0.00      0.00      0.00         1
#          VBG       0.96      0.72      0.83      2204
#       VBG|JJ       0.00      0.00      0.00         1
#       VBG|NN       0.00      0.00      0.00         4
#          VBN       0.81      0.74      0.77      3143
#       VBN|JJ       0.00      0.00      0.00         1
#      VBN|VBD       0.00      0.00      0.00         1
#          VBP       0.95      0.81      0.88      1678
#          VBZ       0.98      0.92      0.95      3118
#          WDT       1.00      0.51      0.68       606
#           WP       0.99      0.99      0.99       354
#          WP$       1.00      0.95      0.97        19
#          WRB       1.00      0.97      0.99       310
#           ``       1.00      1.00      1.00      1177
#
#     accuracy                           0.93    163883
#    macro avg       0.62      0.56      0.57    163883
# weighted avg       0.93      0.93      0.92    163883
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# generating test resullts
alpha = 1
seq = viterbi(test_pairs, train_tag_vocab, alpha)
# Out:
# 100% 9046/9046 [20:14<00:00,  7.45it/s]

# %%
new_seq = []
for sent in seq:
    n_seq = []
    n_seq.append('<START>')
    n_seq.extend(sent)
    new_seq.append(n_seq)
evaluate(test_pairs, new_seq)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            #       0.00      0.00      0.00        22
#            $       0.98      0.99      0.99      1138
#           ''       1.00      1.00      1.00      1423
#            (       1.00      0.96      0.98       249
#            )       1.00      0.98      0.99       252
#            ,       1.00      1.00      1.00      9056
#            .       1.00      1.00      1.00      7035
#            :       1.00      0.99      1.00       983
#      <START>       1.00      1.00      1.00      9046
#       <STOP>       0.98      1.00      0.99      9046
#           CC       0.93      1.00      0.96      4289
#           CD       0.96      0.90      0.93      6023
#           DT       0.87      0.99      0.93     14946
#           EX       0.96      0.45      0.61       174
#           FW       0.00      0.00      0.00        38
#           IN       0.90      0.99      0.94     18147
#           JJ       0.88      0.83      0.85     10704
#          JJR       0.67      0.80      0.73       581
#      JJR|RBR       0.00      0.00      0.00         4
#          JJS       0.79      0.87      0.83       374
#        JJ|IN       0.00      0.00      0.00         1
#           LS       0.00      0.00      0.00        15
#           MD       1.00      0.99      0.99      1674
#           NN       0.91      0.95      0.93     23468
#          NNP       0.93      0.89      0.91     17236
#         NNPS       0.67      0.03      0.05       239
#          NNS       0.98      0.92      0.95     10697
#          PDT       0.00      0.00      0.00        66
#          POS       0.97      1.00      0.98      1638
#          PRP       0.92      0.99      0.95      2930
#         PRP$       0.99      1.00      0.99      1433
#           RB       0.89      0.82      0.85      5853
#          RBR       0.79      0.08      0.15       382
#      RBR|JJR       0.00      0.00      0.00         2
#          RBS       0.80      0.05      0.09        87
#        RB|JJ       0.00      0.00      0.00         2
#           RP       0.00      0.00      0.00       356
#          SYM       0.00      0.00      0.00        11
#           TO       1.00      1.00      1.00      3899
#           UH       0.00      0.00      0.00        20
#           VB       0.86      0.93      0.90      4766
#          VBD       0.91      0.92      0.92      5869
#          VBG       0.97      0.70      0.81      2592
#       VBG|NN       0.00      0.00      0.00         1
#          VBN       0.80      0.74      0.77      3580
#       VBN|JJ       0.00      0.00      0.00         2
#          VBP       0.96      0.83      0.89      2209
#          VBZ       0.97      0.92      0.95      3608
#          WDT       1.00      0.53      0.69       773
#           WP       0.99      0.99      0.99       397
#          WP$       1.00      0.91      0.96        47
#          WRB       1.00      0.97      0.99       425
#           ``       1.00      1.00      1.00      1422
#
#     accuracy                           0.93    189230
#    macro avg       0.70      0.64      0.65    189230
# weighted avg       0.93      0.93      0.93    189230
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
alpha = 0.01
seq = viterbi(test_pairs, train_tag_vocab, alpha)
new_seq = []
for sent in seq:
    n_seq = []
    n_seq.append('<START>')
    n_seq.extend(sent)
    new_seq.append(n_seq)
evaluate(test_pairs, new_seq)
# Out:
# 100% 9046/9046 [20:28<00:00,  7.36it/s]
# [[  21    0    0 ...    0    0    0]
#  [   0 1138    0 ...    0    0    0]
#  [   0    0 1418 ...    0    0    0]
#  ...
#  [   0    0    0 ...   47    0    0]
#  [   0    0    0 ...    0  422    0]
#  [   0    0    0 ...    0    0 1422]]
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            #       1.00      0.95      0.98        22
#            $       0.98      1.00      0.99      1138
#           ''       0.87      1.00      0.93      1423
#            (       1.00      1.00      1.00       249
#            )       1.00      1.00      1.00       252
#            ,       1.00      1.00      1.00      9056
#            .       0.98      1.00      0.99      7035
#            :       1.00      1.00      1.00       983
#      <START>       1.00      1.00      1.00      9046
#       <STOP>       1.00      1.00      1.00      9046
#           CC       0.99      1.00      1.00      4289
#           CD       0.97      0.93      0.95      6023
#           DT       0.99      0.99      0.99     14946
#           EX       0.52      0.94      0.67       174
#           FW       0.12      0.37      0.19        38
#           IN       0.96      0.98      0.97     18147
#        IN|RB       0.00      0.00      0.00         0
#           JJ       0.89      0.86      0.87     10704
#          JJR       0.56      0.91      0.70       581
#      JJR|RBR       0.00      0.00      0.00         4
#          JJS       0.30      0.93      0.46       374
#        JJ|IN       0.00      0.00      0.00         1
#           LS       0.00      0.00      0.00        15
#           MD       0.97      1.00      0.99      1674
#           NN       0.97      0.93      0.95     23468
#          NNP       0.96      0.86      0.91     17236
#         NNPS       0.27      0.56      0.36       239
#          NNS       0.96      0.95      0.96     10697
#          PDT       0.50      0.03      0.06        66
#          POS       0.68      0.98      0.80      1638
#          PRP       0.99      0.99      0.99      2930
#         PRP$       0.70      1.00      0.82      1433
#           RB       0.92      0.86      0.89      5853
#          RBR       0.76      0.34      0.47       382
#      RBR|JJR       0.00      0.00      0.00         2
#          RBS       0.38      0.16      0.23        87
#        RB|JJ       0.00      0.00      0.00         2
#           RP       0.34      0.67      0.45       356
#          SYM       0.90      0.82      0.86        11
#           TO       1.00      1.00      1.00      3899
#           UH       0.80      0.40      0.53        20
#           VB       0.92      0.94      0.93      4766
#          VBD       0.92      0.91      0.92      5869
#          VBG       0.94      0.85      0.89      2592
#       VBG|NN       0.00      0.00      0.00         1
#          VBN       0.79      0.81      0.80      3580
#       VBN|JJ       0.00      0.00      0.00         2
#          VBP       0.90      0.89      0.89      2209
#          VBZ       0.95      0.95      0.95      3608
#          WDT       0.65      0.97      0.78       773
#           WP       0.99      1.00      0.99       397
#          WP$       1.00      1.00      1.00        47
#          WRB       1.00      0.99      1.00       425
#           ``       0.97      1.00      0.99      1422
#
#     accuracy                           0.94    189230
#    macro avg       0.71      0.74      0.71    189230
# weighted avg       0.95      0.94      0.94    189230
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
gold = [str(tag) for sentence in test_pairs for token, tag in sentence]
tokens = [str(token) for sentence in test_pairs for token, tag in sentence]
pred = [tag for sentence in new_seq for tag in sentence]

for p_token, g_token, token in zip(pred, gold, tokens):
    if p_token != g_token:
        print('token:', token)
        print('Prediction:', p_token)
        print('Actual token:', g_token)
        print('.....')
# Out:
# token: Influential
# Prediction: WDT
# Actual token: JJ
# .....
# token: Ways
# Prediction: NNPS
# Actual token: NNP
# .....
# token: working
# Prediction: NN
# Actual token: VBG
# .....
# token: RTC-owned
# Prediction: JJS
# Actual token: JJ
# .....
# token: self-help
# Prediction: EX
# Actual token: NN
# .....
# token: '
# Prediction: POS
# Actual token: ''
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: issued
# Prediction: VBD
# Actual token: VBN
# .....
# token: working
# Prediction: VBG
# Actual token: NN
# .....
# token: Cooke
# Prediction: POS
# Actual token: NNP
# .....
# token: selling
# Prediction: NN
# Actual token: VBG
# .....
# token: Absent
# Prediction: WDT
# Actual token: VB
# .....
# token: complicated
# Prediction: JJ
# Actual token: VBN
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: subtracting
# Prediction: JJR
# Actual token: VBG
# .....
# token: working-capital
# Prediction: JJS
# Actual token: JJ
# .....
# token: Schumer
# Prediction: POS
# Actual token: NNP
# .....
# token: remiss
# Prediction: RP
# Actual token: JJ
# .....
# token: informed
# Prediction: VBD
# Actual token: VBN
# .....
# token: secrecy
# Prediction: JJS
# Actual token: NN
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: Ways
# Prediction: NNPS
# Actual token: NNP
# .....
# token: about
# Prediction: RB
# Actual token: IN
# .....
# token: Hard
# Prediction: WDT
# Actual token: RB
# .....
# token: on
# Prediction: IN
# Actual token: RP
# .....
# token: 's
# Prediction: POS
# Actual token: VBZ
# .....
# token: rushed
# Prediction: VBD
# Actual token: VBN
# .....
# token: around
# Prediction: IN
# Actual token: RP
# .....
# token: filmed
# Prediction: VBN
# Actual token: VBD
# .....
# token: commercial
# Prediction: JJ
# Actual token: NN
# .....
# token: Investments
# Prediction: NNPS
# Actual token: NNP
# .....
# token: around
# Prediction: IN
# Actual token: RP
# .....
# token: half
# Prediction: DT
# Actual token: PDT
# .....
# token: automated
# Prediction: JJ
# Actual token: VBN
# .....
# token: 800-number
# Prediction: NNS
# Actual token: NN
# .....
# token: 800-line
# Prediction: JJS
# Actual token: NN
# .....
# token: received
# Prediction: VBD
# Actual token: VBN
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: double
# Prediction: VB
# Actual token: RB
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: Today
# Prediction: NNP
# Actual token: NN
# .....
# token: Underneath
# Prediction: WDT
# Actual token: IN
# .....
# token: on
# Prediction: IN
# Actual token: RB
# .....
# token: PaineWebber
# Prediction: NNP
# Actual token: NN
# .....
# token: gear
# Prediction: NN
# Actual token: VB
# .....
# token: up
# Prediction: IN
# Actual token: RP
# .....
# token: down
# Prediction: IN
# Actual token: RP
# .....
# token: commercial
# Prediction: JJ
# Actual token: NN
# .....
# token: closed
# Prediction: VBD
# Actual token: VBN
# .....
# token: rush
# Prediction: NN
# Actual token: VB
# .....
# token: that
# Prediction: WDT
# Actual token: DT
# .....
# token: negotiated
# Prediction: VBN
# Actual token: VBD
# .....
# token: commercial
# Prediction: JJ
# Actual token: NN
# .....
# token: 's
# Prediction: POS
# Actual token: VBZ
# .....
# token: most
# Prediction: JJS
# Actual token: RBS
# .....
# token: Taped
# Prediction: WDT
# Actual token: VBN
# .....
# token: advising
# Prediction: VBG
# Actual token: NN
# .....
# token: sell
# Prediction: VB
# Actual token: NN
# .....
# token: on
# Prediction: IN
# Actual token: RP
# .....
# token: lifeline
# Prediction: JJS
# Actual token: NN
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: go
# Prediction: VBP
# Actual token: VB
# .....
# token: further
# Prediction: JJ
# Actual token: RBR
# .....
# token: Lampe
# Prediction: POS
# Actual token: NNP
# .....
# token: changed
# Prediction: VBN
# Actual token: VBD
# .....
# token: revisited
# Prediction: CD
# Actual token: VBN
# .....
# token: fluctuating
# Prediction: .
# Actual token: VBG
# .....
# token: up
# Prediction: RP
# Actual token: RB
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: created
# Prediction: VBN
# Actual token: VBD
# .....
# token: easy-to-film
# Prediction: JJS
# Actual token: JJ
# .....
# token: Stand
# Prediction: VB
# Actual token: VBP
# .....
# token: commercial
# Prediction: JJ
# Actual token: NN
# .....
# token: Leadership
# Prediction: EX
# Actual token: NN
# .....
# token: Example
# Prediction: PRP$
# Actual token: NN
# .....
# token: said
# Prediction: VBN
# Actual token: VBD
# .....
# token: straightening
# Prediction: RP
# Actual token: VBG
# .....
# token: Cathleen
# Prediction: VBN
# Actual token: NNP
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: en
# Prediction: IN
# Actual token: FW
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: around
# Prediction: IN
# Actual token: RP
# .....
# token: Ad
# Prediction: NNP
# Actual token: NN
# .....
# token: Notes
# Prediction: NNPS
# Actual token: NNS
# .....
# token: ARNOLD
# Prediction: WDT
# Actual token: NNP
# .....
# token: Eskandarian
# Prediction: POS
# Actual token: NNP
# .....
# token: WCRS\/Boston
# Prediction: POS
# Actual token: NNP
# .....
# token: reached
# Prediction: VBN
# Actual token: VBD
# .....
# token: majority
# Prediction: NN
# Actual token: JJ
# .....
# token: Eskandarian
# Prediction: POS
# Actual token: NNP
# .....
# token: Verret
# Prediction: POS
# Actual token: NNP
# .....
# token: Separately
# Prediction: RB
# Actual token: NNP
# .....
# token: named
# Prediction: VBN
# Actual token: VBD
# .....
# token: estimated
# Prediction: JJ
# Actual token: VBN
# .....
# token: EDUCATION
# Prediction: WDT
# Actual token: NN
# .....
# token: ADS
# Prediction: NNPS
# Actual token: NNS
# .....
# token: 142-page
# Prediction: JJS
# Actual token: JJ
# .....
# token: Corporate
# Prediction: JJ
# Actual token: NNP
# .....
# token: Elite
# Prediction: NNS
# Actual token: NNP
# .....
# token: kicks
# Prediction: VBZ
# Actual token: NNS
# .....
# token: Business
# Prediction: NN
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: VBZ
# .....
# token: 1
# Prediction: CD
# Actual token: LS
# .....
# token: like
# Prediction: IN
# Actual token: JJ
# .....
# token: 2
# Prediction: CD
# Actual token: LS
# .....
# token: averages
# Prediction: NNS
# Actual token: VBZ
# .....
# token: deep
# Prediction: JJ
# Actual token: RB
# .....
# token: 3
# Prediction: CD
# Actual token: LS
# .....
# token: 1,118
# Prediction: RP
# Actual token: CD
# .....
# token: publishable
# Prediction: PRP$
# Actual token: JJ
# .....
# token: Baseball
# Prediction: NNP
# Actual token: NN
# .....
# token: that
# Prediction: WDT
# Actual token: DT
# .....
# token: mean
# Prediction: JJ
# Actual token: NN
# .....
# token: ol'
# Prediction: NNS
# Actual token: JJ
# .....
# token: caught
# Prediction: VBN
# Actual token: VBD
# .....
# token: Giants
# Prediction: NNPS
# Actual token: NNP
# .....
# token: home-team
# Prediction: JJS
# Actual token: JJ
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: NNP
# .....
# token: Dodgers
# Prediction: NNPS
# Actual token: NNP
# .....
# token: much
# Prediction: RB
# Actual token: JJ
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: NNP
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: NNP
# .....
# token: 2-0
# Prediction: JJS
# Actual token: CD
# .....
# token: Reuschel
# Prediction: POS
# Actual token: NNP
# .....
# token: left-field
# Prediction: JJS
# Actual token: JJ
# .....
# token: stands
# Prediction: VBZ
# Actual token: NNS
# .....
# token: runs
# Prediction: VBZ
# Actual token: NNS
# .....
# token: batted
# Prediction: JJR
# Actual token: VBD
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: NNP
# .....
# token: take
# Prediction: VB
# Actual token: VBP
# .....
# token: later
# Prediction: RB
# Actual token: RBR
# .....
# token: green
# Prediction: JJ
# Actual token: NN
# .....
# token: salted
# Prediction: .
# Actual token: VBD
# .....
# token: red-haired
# Prediction: ''
# Actual token: JJ
# .....
# token: at
# Prediction: IN
# Actual token: NN
# .....
# token: bats
# Prediction: PRP$
# Actual token: NNS
# .....
# token: 'd
# Prediction: MD
# Actual token: VBD
# .....
# token: had
# Prediction: VBD
# Actual token: VBN
# .....
# token: 1-for-17
# Prediction: RP
# Actual token: NN
# .....
# token: A-men
# Prediction: JJS
# Actual token: NNS
# .....
# token: batting
# Prediction: NN
# Actual token: VBG
# .....
# token: Nos.
# Prediction: .
# Actual token: NNS
# .....
# token: a.k.a.
# Prediction: ''
# Actual token: JJ
# .....
# token: bottom
# Prediction: JJ
# Actual token: NN
# .....
# token: Right-hander
# Prediction: WDT
# Actual token: JJ
# .....
# token: Giants
# Prediction: NNPS
# Actual token: NNP
# .....
# token: zero
# Prediction: CD
# Actual token: NN
# .....
# token: ledger
# Prediction: POS
# Actual token: NN
# .....
# token: That
# Prediction: DT
# Actual token: IN
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: NNP
# .....
# token: American
# Prediction: JJ
# Actual token: NNP
# .....
# token: 21-9
# Prediction: JJS
# Actual token: CD
# .....
# token: plus
# Prediction: CC
# Actual token: IN
# .....
# token: up
# Prediction: IN
# Actual token: RP
# .....
# token: split-fingered
# Prediction: JJS
# Actual token: JJ
# .....
# token: that
# Prediction: WDT
# Actual token: IN
# .....
# token: overcame
# Prediction: VBP
# Actual token: VBD
# .....
# token: early
# Prediction: RB
# Actual token: JJ
# .....
# token: struggles
# Prediction: VBZ
# Actual token: NNS
# .....
# token: Giants
# Prediction: NNPS
# Actual token: NNP
# .....
# token: but
# Prediction: CC
# Actual token: RB
# .....
# token: out
# Prediction: RP
# Actual token: RB
# .....
# token: there
# Prediction: EX
# Actual token: RB
# .....
# token: split-finger
# Prediction: IN
# Actual token: NN
# .....
# token: before
# Prediction: IN
# Actual token: RB
# .....
# token: marveled
# Prediction: VBZ
# Actual token: VBD
# .....
# token: Giant
# Prediction: NNP
# Actual token: JJ
# .....
# token: ex-hurler
# Prediction: JJS
# Actual token: NN
# .....
# token: leading
# Prediction: JJ
# Actual token: VBG
# .....
# token: dives
# Prediction: VBP
# Actual token: VBZ
# .....
# token: lunging
# Prediction: JJS
# Actual token: VBG
# .....
# token: upshot
# Prediction: JJS
# Actual token: NN
# .....
# token: downshoot
# Prediction: JJS
# Actual token: NN
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: NNP
# .....
# token: tonight
# Prediction: NN
# Actual token: RB
# .....
# token: fest
# Prediction: JJS
# Actual token: NN
# .....
# token: stat
# Prediction: JJS
# Actual token: NN
# .....
# token: with
# Prediction: IN
# Actual token: RP
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: that
# Prediction: IN
# Actual token: WDT
# .....
# token: 2-0
# Prediction: VBN
# Actual token: CD
# .....
# token: Series
# Prediction: NN
# Actual token: NNP
# .....
# token: leads
# Prediction: VBZ
# Actual token: NNS
# .....
# token: on
# Prediction: IN
# Actual token: RB
# .....
# token: average
# Prediction: JJ
# Actual token: NN
# .....
# token: rooters
# Prediction: POS
# Actual token: NNS
# .....
# token: One
# Prediction: CD
# Actual token: NN
# .....
# token: Series
# Prediction: NN
# Actual token: NNP
# .....
# token: Subway
# Prediction: JJS
# Actual token: NNP
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: conveyance
# Prediction: NNS
# Actual token: NN
# .....
# token: Desire
# Prediction: EX
# Actual token: NN
# .....
# token: calm
# Prediction: JJ
# Actual token: NN
# .....
# token: Partisans
# Prediction: WDT
# Actual token: NNS
# .....
# token: combatants
# Prediction: CD
# Actual token: NNS
# .....
# token: 49,000-plus
# Prediction: JJS
# Actual token: JJ
# .....
# token: Coliseum
# Prediction: POS
# Actual token: NNP
# .....
# token: booed
# Prediction: JJR
# Actual token: VBD
# .....
# token: further
# Prediction: JJ
# Actual token: RBR
# .....
# token: as
# Prediction: IN
# Actual token: RB
# .....
# token: emblems
# Prediction: JJR
# Actual token: NNS
# .....
# token: Giants
# Prediction: NNPS
# Actual token: NNP
# .....
# token: Series
# Prediction: NN
# Actual token: NNP
# .....
# token: septuagenarian
# Prediction: POS
# Actual token: NN
# .....
# token: Coliseum
# Prediction: JJS
# Actual token: NN
# .....
# token: go
# Prediction: VB
# Actual token: NN
# .....
# token: apathy
# Prediction: JJS
# Actual token: NN
# .....
# token: civility
# Prediction: JJR
# Actual token: NN
# .....
# token: springs
# Prediction: VBN
# Actual token: VBZ
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: NNP
# .....
# token: Yankees-Mets
# Prediction: POS
# Actual token: JJ
# .....
# token: Sox
# Prediction: NNPS
# Actual token: NNP
# .....
# token: hey
# Prediction: $
# Actual token: UH
# .....
# token: uniformed
# Prediction: RP
# Actual token: JJ
# .....
# token: police
# Prediction: NN
# Actual token: NNS
# .....
# token: suicidal
# Prediction: JJS
# Actual token: JJ
# .....
# token: bonnets
# Prediction: JJS
# Actual token: NNS
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: NNP
# .....
# token: for
# Prediction: IN
# Actual token: RP
# .....
# token: opening
# Prediction: NN
# Actual token: JJ
# .....
# token: twiggy-looking
# Prediction: JJS
# Actual token: JJ
# .....
# token: second-year
# Prediction: ''
# Actual token: JJ
# .....
# token: afield
# Prediction: NNS
# Actual token: RB
# .....
# token: ditto
# Prediction: $
# Actual token: NN
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: NNP
# .....
# token: three-run
# Prediction: JJS
# Actual token: JJ
# .....
# token: homered
# Prediction: JJR
# Actual token: VBD
# .....
# token: Bashers
# Prediction: POS
# Actual token: NNP
# .....
# token: that
# Prediction: WDT
# Actual token: IN
# .....
# token: autograph
# Prediction: JJS
# Actual token: NN
# .....
# token: autograph
# Prediction: JJS
# Actual token: NN
# .....
# token: power-hitter
# Prediction: ``
# Actual token: NN
# .....
# token: McGwire
# Prediction: NNP
# Actual token: NN
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: 's
# Prediction: POS
# Actual token: NNP
# .....
# token: co-hero
# Prediction: JJS
# Actual token: NN
# .....
# token: exemplifies
# Prediction: VBP
# Actual token: VBZ
# .....
# token: hot-cold
# Prediction: JJS
# Actual token: JJ
# .....
# token: smoked
# Prediction: VBP
# Actual token: VBD
# .....
# token: walks
# Prediction: VBZ
# Actual token: NNS
# .....
# token: bats
# Prediction: PRP$
# Actual token: NNS
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: 3-for-3
# Prediction: RP
# Actual token: JJ
# .....
# token: scoring
# Prediction: JJR
# Actual token: VBG
# .....
# token: groove
# Prediction: JJS
# Actual token: NN
# .....
# token: Giants
# Prediction: NNPS
# Actual token: NNP
# .....
# token: 3-4-5
# Prediction: JJS
# Actual token: CD
# .....
# token: runs
# Prediction: VBZ
# Actual token: NNS
# .....
# token: batted
# Prediction: VBP
# Actual token: VBN
# .....
# token: in
# Prediction: IN
# Actual token: RP
# .....
# token: 5-for-24
# Prediction: NNS
# Actual token: CD
# .....
# token: ribbies
# Prediction: JJR
# Actual token: NNS
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: as
# Prediction: IN
# Actual token: RB
# .....
# token: Giants
# Prediction: NNPS
# Actual token: NNP
# .....
# token: hope
# Prediction: VBP
# Actual token: NN
# .....
# token: Series
# Prediction: NN
# Actual token: NNP
# .....
# token: Dusty
# Prediction: .
# Actual token: NNP
# .....
# token: come
# Prediction: VBN
# Actual token: VB
# .....
# token: slugger
# Prediction: POS
# Actual token: NN
# .....
# token: offered
# Prediction: VBN
# Actual token: VBD
# .....
# token: know
# Prediction: VB
# Actual token: VBP
# .....
# token: buy-back
# Prediction: NN
# Actual token: JJ
# .....
# token: Average
# Prediction: NNP
# Actual token: JJ
# .....
# token: 75.8
# Prediction: VB
# Actual token: CD
# .....
# token: 82.1
# Prediction: PRP$
# Actual token: CD
# .....
# token: Revenue
# Prediction: NNP
# Actual token: NN
# .....
# token: half
# Prediction: DT
# Actual token: NN
# .....
# token: better
# Prediction: JJR
# Actual token: VB
# .....
# token: overseas
# Prediction: JJ
# Actual token: RB
# .....
# token: computerized
# Prediction: JJ
# Actual token: VBN
# .....
# token: registers
# Prediction: .
# Actual token: NNS
# .....
# token: Sanjiv
# Prediction: VBN
# Actual token: NNP
# .....
# token: Hingorani
# Prediction: POS
# Actual token: NNP
# .....
# token: Brothers
# Prediction: NNPS
# Actual token: NNP
# .....
# token: Hingorani
# Prediction: POS
# Actual token: NNP
# .....
# token: Revenue
# Prediction: NNP
# Actual token: NN
# .....
# token: composite
# Prediction: JJ
# Actual token: NN
# .....
# token: Firms
# Prediction: NNPS
# Actual token: NNP
# .....
# token: Link
# Prediction: NNPS
# Actual token: VBP
# .....
# token: Analysts
# Prediction: NNS
# Actual token: NNP
# .....
# token: Pay
# Prediction: JJS
# Actual token: NN
# .....
# token: Performance
# Prediction: NNP
# Actual token: NN
# .....
# token: tuning
# Prediction: VBN
# Actual token: VBG
# .....
# token: in
# Prediction: IN
# Actual token: RP
# .....
# token: limit
# Prediction: NN
# Actual token: VB
# .....
# token: maligned
# Prediction: ''
# Actual token: VBN
# .....
# token: future
# Prediction: JJ
# Actual token: NN
# .....
# token: best
# Prediction: JJS
# Actual token: RBS
# .....
# token: force
# Prediction: VBP
# Actual token: NN
# .....
# token: account-churning
# Prediction: PRP$
# Actual token: NN
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: novelty
# Prediction: JJS
# Actual token: NN
# .....
# token: Palamara
# Prediction: POS
# Actual token: NNP
# .....
# token: up
# Prediction: RP
# Actual token: RB
# .....
# token: most
# Prediction: JJS
# Actual token: RBS
# .....
# token: States
# Prediction: NNPS
# Actual token: NNP
# .....
# token: 2:30
# Prediction: ''
# Actual token: CD
# .....
# token: 3:30
# Prediction: ''
# Actual token: CD
# .....
# token: out
# Prediction: IN
# Actual token: RP
# .....
# token: lunchtime
# Prediction: PRP$
# Actual token: NN
# .....
# token: near-panic
# Prediction: NN
# Actual token: JJ
# .....
# token: Street-inspired
# Prediction: POS
# Actual token: JJ
# .....
# token: So
# Prediction: RB
# Actual token: IN
# .....
# token: in
# Prediction: IN
# Actual token: RB
# .....
# token: mixed
# Prediction: VBN
# Actual token: JJ
# .....
# token: closed
# Prediction: VBD
# Actual token: VBN
# .....
# token: off
# Prediction: RP
# Actual token: JJ
# .....
# token: less-than-alarming
# Prediction: JJR
# Actual token: JJ
# .....
# token: trading
# Prediction: NN
# Actual token: VBG
# .....
# token: Finsbury
# Prediction: PRP$
# Actual token: NNP
# .....
# token: Share
# Prediction: NN
# Actual token: NNP
# .....
# token: Index
# Prediction: NN
# Actual token: NNP
# .....
# token: Red
# Prediction: NNP
# Actual token: JJ
# .....
# token: 2076.8
# Prediction: PRP$
# Actual token: CD
# .....
# token: off
# Prediction: RB
# Actual token: IN
# .....
# token: 157.1
# Prediction: VBN
# Actual token: CD
# .....
# token: Palamara
# Prediction: POS
# Actual token: NNP
# .....
# token: good-humored
# Prediction: ''
# Actual token: JJ
# .....
# token: 15-trader
# Prediction: JJS
# Actual token: JJ
# .....
# token: trading
# Prediction: VBG
# Actual token: NN
# .....
# token: most
# Prediction: RBS
# Actual token: JJS
# .....
# token: Newcastle
# Prediction: JJR
# Actual token: NNP
# .....
# token: DRG
# Prediction: ''
# Actual token: NNP
# .....
# token: Seconds
# Prediction: WDT
# Actual token: NNS
# .....
# token: later
# Prediction: RB
# Actual token: RBR
# .....
# token: 7,500-share
# Prediction: JJS
# Actual token: JJ
# .....
# token: sell
# Prediction: VB
# Actual token: NN
# .....
# token: Newcastle
# Prediction: JJR
# Actual token: NNP
# .....
# token: in
# Prediction: IN
# Actual token: RP
# .....
# token: next
# Prediction: IN
# Actual token: JJ
# .....
# token: no-smoking
# Prediction: JJS
# Actual token: JJ
# .....
# token: forlorn
# Prediction: CD
# Actual token: JJ
# .....
# token: off
# Prediction: RP
# Actual token: RB
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: let
# Prediction: VBD
# Actual token: VB
# .....
# token: pick
# Prediction: NN
# Actual token: VB
# .....
# token: up
# Prediction: RP
# Actual token: IN
# .....
# token: punched
# Prediction: JJR
# Actual token: VBD
# .....
# token: quotes
# Prediction: VBZ
# Actual token: NNS
# .....
# token: 845
# Prediction: PRP$
# Actual token: CD
# .....
# token: feelers
# Prediction: PRP$
# Actual token: NNS
# .....
# token: dominated
# Prediction: VBD
# Actual token: VBN
# .....
# token: selling
# Prediction: VBG
# Actual token: NN
# .....
# token: abandoned
# Prediction: VBN
# Actual token: VBD
# .....
# token: Fundamentally
# Prediction: EX
# Actual token: RB
# .....
# token: whisper
# Prediction: JJS
# Actual token: NN
# .....
# token: right
# Prediction: RB
# Actual token: JJ
# .....
# token: Linger
# Prediction: VB
# Actual token: NNP
# .....
# token: Futures
# Prediction: NNPS
# Actual token: NNP
# .....
# token: half
# Prediction: PDT
# Actual token: NN
# .....
# token: lunchtime
# Prediction: NNS
# Actual token: NN
# .....
# token: gathered
# Prediction: VBN
# Actual token: VBD
# .....
# token: nearby
# Prediction: JJ
# Actual token: RB
# .....
# token: subdued
# Prediction: VBN
# Actual token: JJ
# .....
# token: 12:49
# Prediction: PRP$
# Actual token: CD
# .....
# token: 2029.7
# Prediction: ''
# Actual token: CD
# .....
# token: off
# Prediction: RB
# Actual token: IN
# .....
# token: 204.2
# Prediction: VBN
# Actual token: CD
# .....
# token: down
# Prediction: IN
# Actual token: RB
# .....
# token: off
# Prediction: RB
# Actual token: IN
# .....
# token: suspended
# Prediction: VBD
# Actual token: VBN
# .....
# token: 's
# Prediction: POS
# Actual token: VBZ
# .....
# token: 2:30
# Prediction: PRP$
# Actual token: CD
# .....
# token: opening
# Prediction: NN
# Actual token: VBG
# .....
# token: traded
# Prediction: VBN
# Actual token: VBD
# .....
# token: Streeter
# Prediction: POS
# Actual token: NNP
# .....
# token: as
# Prediction: IN
# Actual token: RB
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: created
# Prediction: VBD
# Actual token: VBN
# .....
# token: Receipts
# Prediction: NNPS
# Actual token: NNP
# .....
# token: Streeter
# Prediction: POS
# Actual token: NNP
# .....
# token: Motors
# Prediction: NNPS
# Actual token: NNP
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: better
# Prediction: JJR
# Actual token: RBR
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: Markets
# Prediction: NNPS
# Actual token: NNP
# .....
# token: indicated
# Prediction: VBN
# Actual token: VBD
# .....
# token: later
# Prediction: RB
# Actual token: RBR
# .....
# token: Rally
# Prediction: NNP
# Actual token: NN
# .....
# token: Rally
# Prediction: NNP
# Actual token: NN
# .....
# token: Rally
# Prediction: NNP
# Actual token: NN
# .....
# token: 2163.4
# Prediction: PRP$
# Actual token: CD
# .....
# token: high
# Prediction: JJ
# Actual token: NN
# .....
# token: off
# Prediction: RB
# Actual token: IN
# .....
# token: Nitze
# Prediction: POS
# Actual token: NNP
# .....
# token: Notable
# Prediction: $
# Actual token: NNP
# .....
# token: Quotable
# Prediction: JJR
# Actual token: NNP
# .....
# token: wrong
# Prediction: JJ
# Actual token: NN
# .....
# token: once
# Prediction: RB
# Actual token: IN
# .....
# token: pretty
# Prediction: JJ
# Actual token: RB
# .....
# token: as
# Prediction: IN
# Actual token: RB
# .....
# token: once
# Prediction: RB
# Actual token: IN
# .....
# token: Do
# Prediction: NNP
# Actual token: VBP
# .....
# token: pessimist
# Prediction: JJS
# Actual token: NN
# .....
# token: Tremdine
# Prediction: POS
# Actual token: NNP
# .....
# token: leveraged
# Prediction: JJ
# Actual token: VBN
# .....
# token: collapsed
# Prediction: JJ
# Actual token: VBN
# .....
# token: Airlines
# Prediction: NNPS
# Actual token: NNP
# .....
# token: spurred
# Prediction: VBN
# Actual token: VBD
# .....
# token: parting
# Prediction: NN
# Actual token: VBG
# .....
# token: Airlines
# Prediction: NNPS
# Actual token: NNP
# .....
# token: deputy
# Prediction: JJ
# Actual token: NN
# .....
# token: sent
# Prediction: VBN
# Actual token: VBD
# .....
# token: come
# Prediction: VB
# Actual token: VBN
# .....
# token: wiggle
# Prediction: VBP
# Actual token: NN
# .....
# token: Aides
# Prediction: WDT
# Actual token: NNS
# .....
# token: want
# Prediction: VB
# Actual token: VBP
# .....
# token: leveraged
# Prediction: JJ
# Actual token: VBN
# .....
# token: block
# Prediction: VB
# Actual token: NN
# .....
# token: view
# Prediction: NN
# Actual token: VBP
# .....
# token: airline-acquisition
# Prediction: JJS
# Actual token: JJ
# .....
# token: result
# Prediction: NN
# Actual token: VB
# .....
# token: profiteers
# Prediction: RP
# Actual token: NNS
# .....
# token: in
# Prediction: IN
# Actual token: RP
# .....
# token: cost-effective
# Prediction: ''
# Actual token: JJ
# .....
# token: disapproved
# Prediction: VBN
# Actual token: VBD
# .....
# token: backing
# Prediction: NN
# Actual token: VBG
# .....
# token: expressed
# Prediction: VBD
# Actual token: VBN
# .....
# token: dissenters
# Prediction: JJS
# Actual token: NNS
# .....
# token: spin-off
# Prediction: NN
# Actual token: JJ
# .....
# token: striking
# Prediction: JJ
# Actual token: VBG
# .....
# token: Boeing
# Prediction: NNP
# Actual token: VBG
# .....
# token: Machinists
# Prediction: NNS
# Actual token: NNP
# .....
# token: Boeing
# Prediction: NNP
# Actual token: VBG
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: Work
# Prediction: NNP
# Actual token: NN
# .....
# token: manning
# Prediction: VBP
# Actual token: VBG
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: 11,700
# Prediction: JJS
# Actual token: CD
# .....
# token: right-to-work
# Prediction: POS
# Actual token: JJ
# .....
# token: Renton
# Prediction: NNS
# Actual token: NNP
# .....
# token: Union
# Prediction: NNP
# Actual token: NN
# .....
# token: Partners
# Prediction: NNPS
# Actual token: NNP
# .....
# token: Securities
# Prediction: NNPS
# Actual token: NNP
# .....
# token: considered
# Prediction: VBN
# Actual token: VBD
# .....
# token: composite
# Prediction: JJ
# Actual token: NN
# .....
# token: off
# Prediction: RP
# Actual token: IN
# .....
# token: phase
# Prediction: VB
# Actual token: NN
# .....
# token: out
# Prediction: RP
# Actual token: IN
# .....
# token: manufacturing
# Prediction: NN
# Actual token: VBG
# .....
# token: Trizec
# Prediction: VB
# Actual token: NNP
# .....
# token: Trizec
# Prediction: JJS
# Actual token: NNP
# .....
# token: executive
# Prediction: NN
# Actual token: JJ
# .....
# token: European
# Prediction: NNP
# Actual token: JJ
# .....
# token: further
# Prediction: RB
# Actual token: JJ
# .....
# token: hardest
# Prediction: RBS
# Actual token: JJS
# .....
# token: hit
# Prediction: VBN
# Actual token: NN
# .....
# token: off
# Prediction: RP
# Actual token: JJ
# .....
# token: as
# Prediction: IN
# Actual token: RB
# .....
# token: back
# Prediction: RP
# Actual token: RB
# .....
# token: down
# Prediction: RP
# Actual token: RB
# .....
# token: West
# Prediction: NNP
# Actual token: JJ
# .....
# token: German
# Prediction: NNP
# Actual token: JJ
# .....
# token: Prices
# Prediction: NNS
# Actual token: NNP
# .....
# token: disrupted
# Prediction: VBN
# Actual token: VBD
# .....
# token: FRANKFURT
# Prediction: WDT
# Actual token: NNP
# .....
# token: 1385.72
# Prediction: PRP$
# Actual token: CD
# .....
# token: 203.56
# Prediction: VBN
# Actual token: CD
# .....
# token: reacted
# Prediction: VBN
# Actual token: VBD
# .....
# token: Insam
# Prediction: POS
# Actual token: NNP
# .....
# token: Liechtenstein
# Prediction: PRP$
# Actual token: NNP
# .....
# token: West
# Prediction: NNP
# Actual token: JJ
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: because
# Prediction: IN
# Actual token: RB
# .....
# token: Longley
# Prediction: POS
# Actual token: NNP
# .....
# token: Institutional
# Prediction: NNP
# Actual token: JJ
# .....
# token: many
# Prediction: JJ
# Actual token: DT
# .....
# token: before
# Prediction: IN
# Actual token: RB
# .....
# token: Far
# Prediction: NNP
# Actual token: JJ
# .....
# token: Eastern
# Prediction: NNP
# Actual token: JJ
# .....
# token: little
# Prediction: JJ
# Actual token: RB
# .....
# token: surprised
# Prediction: JJ
# Actual token: VBN
# .....
# token: most
# Prediction: RBS
# Actual token: JJS
# .....
# token: swift
# Prediction: JJ
# Actual token: NN
# .....
# token: high
# Prediction: JJ
# Actual token: NN
# .....
# token: 1657.61
# Prediction: PRP$
# Actual token: CD
# .....
# token: Yet
# Prediction: CC
# Actual token: RB
# .....
# token: cropped
# Prediction: VBN
# Actual token: VBD
# .....
# token: recovers
# Prediction: .
# Actual token: VBZ
# .....
# token: Share
# Prediction: NN
# Actual token: NNP
# .....
# token: Index
# Prediction: NN
# Actual token: NNP
# .....
# token: off
# Prediction: RP
# Actual token: IN
# .....
# token: 2163.4
# Prediction: PRP$
# Actual token: CD
# .....
# token: high
# Prediction: JJ
# Actual token: NN
# .....
# token: plunged
# Prediction: VBN
# Actual token: VBD
# .....
# token: 204.2
# Prediction: RP
# Actual token: CD
# .....
# token: 12:49
# Prediction: PRP$
# Actual token: CD
# .....
# token: p.m
# Prediction: RB
# Actual token: NN
# .....
# token: Managers
# Prediction: NNPS
# Actual token: NNP
# .....
# token: Attracted
# Prediction: WDT
# Actual token: VBN
# .....
# token: 959.3
# Prediction: VBN
# Actual token: CD
# .....
# token: PARIS
# Prediction: WDT
# Actual token: NNP
# .....
# token: Late
# Prediction: RB
# Actual token: JJ
# .....
# token: buying
# Prediction: VBG
# Actual token: NN
# .....
# token: CAC
# Prediction: JJS
# Actual token: NNP
# .....
# token: 523.6
# Prediction: PRP$
# Actual token: CD
# .....
# token: before
# Prediction: IN
# Actual token: RB
# .....
# token: Vigier
# Prediction: POS
# Actual token: NNP
# .....
# token: Dupont
# Prediction: POS
# Actual token: NNP
# .....
# token: spread
# Prediction: NN
# Actual token: VBD
# .....
# token: up
# Prediction: RP
# Actual token: RB
# .....
# token: sell
# Prediction: VB
# Actual token: NN
# .....
# token: mid-conversation
# Prediction: PRP$
# Actual token: NN
# .....
# token: buys
# Prediction: VBZ
# Actual token: NNS
# .....
# token: Trading
# Prediction: NNP
# Actual token: NN
# .....
# token: doubled
# Prediction: VBN
# Actual token: VBD
# .....
# token: net
# Prediction: JJ
# Actual token: NN
# .....
# token: Securities
# Prediction: NNPS
# Actual token: NNP
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: composite
# Prediction: JJ
# Actual token: NN
# .....
# token: medium
# Prediction: NN
# Actual token: JJ
# .....
# token: remain
# Prediction: VB
# Actual token: VBP
# .....
# token: classified
# Prediction: VBN
# Actual token: JJ
# .....
# token: non-accruing
# Prediction: PRP$
# Actual token: JJ
# .....
# token: Income
# Prediction: NNP
# Actual token: NN
# .....
# token: corporate-finance
# Prediction: JJ
# Actual token: NN
# .....
# token: trading-related
# Prediction: IN
# Actual token: JJ
# .....
# token: Non-interest
# Prediction: WDT
# Actual token: JJ
# .....
# token: doubled
# Prediction: VBN
# Actual token: VBD
# .....
# token: continued
# Prediction: JJ
# Actual token: VBN
# .....
# token: remaining
# Prediction: VBG
# Actual token: JJ
# .....
# token: contrasted
# Prediction: VBN
# Actual token: VBD
# .....
# token: Southeast
# Prediction: JJ
# Actual token: NNP
# .....
# token: Nonperformers
# Prediction: WDT
# Actual token: NNS
# .....
# token: most
# Prediction: JJS
# Actual token: RBS
# .....
# token: offset
# Prediction: VBN
# Actual token: VBD
# .....
# token: Southeast
# Prediction: JJ
# Actual token: NNP
# .....
# token: as
# Prediction: IN
# Actual token: RB
# .....
# token: paid
# Prediction: VBD
# Actual token: VBN
# .....
# token: helped
# Prediction: VBN
# Actual token: VBD
# .....
# token: squeeze
# Prediction: NN
# Actual token: VB
# .....
# token: Southeast
# Prediction: JJ
# Actual token: NNP
# .....
# token: composite
# Prediction: JJ
# Actual token: NN
# .....
# token: formed
# Prediction: VBD
# Actual token: VBN
# .....
# token: remnants
# Prediction: JJS
# Actual token: NNS
# .....
# token: failed
# Prediction: JJ
# Actual token: VBN
# .....
# token: RepublicBank
# Prediction: POS
# Actual token: NNP
# .....
# token: bottom
# Prediction: NN
# Actual token: JJ
# .....
# token: third-quarter
# Prediction: JJ
# Actual token: NN
# .....
# token: failed
# Prediction: JJ
# Actual token: VBN
# .....
# token: real
# Prediction: JJ
# Actual token: NN
# .....
# token: low-yielding
# Prediction: JJS
# Actual token: JJ
# .....
# token: inter-bank
# Prediction: PRP$
# Actual token: JJ
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: offset
# Prediction: VBN
# Actual token: VBD
# .....
# token: depressed
# Prediction: JJ
# Actual token: VBN
# .....
# token: Nonperforming
# Prediction: JJ
# Actual token: VBG
# .....
# token: ago
# Prediction: IN
# Actual token: RB
# .....
# token: foreign-debt
# Prediction: NN
# Actual token: JJ
# .....
# token: before
# Prediction: IN
# Actual token: RB
# .....
# token: Non-interest
# Prediction: WDT
# Actual token: JJ
# .....
# token: Non-interest
# Prediction: WDT
# Actual token: JJ
# .....
# token: revised
# Prediction: JJ
# Actual token: VBN
# .....
# token: Communications
# Prediction: NNPS
# Actual token: NNP
# .....
# token: revised
# Prediction: JJ
# Actual token: VBN
# .....
# token: remaining
# Prediction: VBG
# Actual token: JJ
# .....
# token: as
# Prediction: IN
# Actual token: RB
# .....
# token: remaining
# Prediction: VBG
# Actual token: JJ
# .....
# token: purchase
# Prediction: VB
# Actual token: NN
# .....
# token: operate
# Prediction: VBP
# Actual token: VB
# .....
# token: filed
# Prediction: VBD
# Actual token: VBN
# .....
# token: Securities
# Prediction: NNPS
# Actual token: NNP
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: remaining
# Prediction: VBG
# Actual token: JJ
# .....
# token: Associates
# Prediction: NNPS
# Actual token: NNP
# .....
# token: concerns
# Prediction: NNS
# Actual token: VBZ
# .....
# token: dispute-settlement
# Prediction: NNS
# Actual token: JJ
# .....
# token: U.S.-Canadian
# Prediction: JJS
# Actual token: JJ
# .....
# token: herring
# Prediction: JJR
# Actual token: NN
# .....
# token: violate
# Prediction: VB
# Actual token: VBP
# .....
# token: suffered
# Prediction: VBD
# Actual token: VBN
# .....
# token: fish-processing
# Prediction: POS
# Actual token: JJ
# .....
# token: Canadian
# Prediction: JJ
# Actual token: NNP
# .....
# token: Crosbie
# Prediction: POS
# Actual token: NNP
# .....
# token: dispute-settlement
# Prediction: JJS
# Actual token: JJ
# .....
# token: seeming
# Prediction: JJS
# Actual token: JJ
# .....
# token: contradiction
# Prediction: FW
# Actual token: NN
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: British
# Prediction: JJ
# Actual token: NNP
# .....
# token: dispute-settlement
# Prediction: JJS
# Actual token: JJ
# .....
# token: expect
# Prediction: VB
# Actual token: VBP
# .....
# token: set
# Prediction: VBD
# Actual token: VBN
# .....
# token: up
# Prediction: RP
# Actual token: NNP
# .....
# token: fish-export
# Prediction: NNS
# Actual token: JJ
# .....
# token: fish-processing
# Prediction: POS
# Actual token: JJ
# .....
# token: Idle
# Prediction: WDT
# Actual token: JJ
# .....
# token: Thought
# Prediction: NNP
# Actual token: NN
# .....
# token: heed
# Prediction: VB
# Actual token: NN
# .....
# token: while
# Prediction: IN
# Actual token: VB
# .....
# token: Character
# Prediction: WDT
# Actual token: NN
# .....
# token: Richstone
# Prediction: POS
# Actual token: NNP
# .....
# token: Telecussed
# Prediction: WDT
# Actual token: VBD
# .....
# token: intercept
# Prediction: JJS
# Actual token: NN
# .....
# token: 'Cause
# Prediction: WDT
# Actual token: IN
# .....
# token: Emmons
# Prediction: POS
# Actual token: NNP
# .....
# token: BancOklahoma
# Prediction: WDT
# Actual token: NNP
# .....
# token: agreed
# Prediction: VBD
# Actual token: VBN
# .....
# token: subordinated
# Prediction: JJ
# Actual token: VBN
# .....
# token: open-bank
# Prediction: PRP$
# Actual token: JJ
# .....
# token: BancOklahoma
# Prediction: VB
# Actual token: NNP
# .....
# token: preferred
# Prediction: JJ
# Actual token: VBN
# .....
# token: BancOklahoma
# Prediction: PRP$
# Actual token: NNP
# .....
# token: BancOklahoma
# Prediction: PRP$
# Actual token: NNP
# .....
# token: subsidiary
# Prediction: NN
# Actual token: JJ
# .....
# token: BancOklahoma
# Prediction: PRP$
# Actual token: NNP
# .....
# token: preferred
# Prediction: JJ
# Actual token: VBN
# .....
# token: Kudlow
# Prediction: POS
# Actual token: NNP
# .....
# token: Global
# Prediction: JJ
# Actual token: NNP
# .....
# token: Were
# Prediction: VBD
# Actual token: VB
# .....
# token: paves
# Prediction: .
# Actual token: VBZ
# .....
# token: Argentina
# Prediction: NNP
# Actual token: NN
# .....
# token: up
# Prediction: RP
# Actual token: IN
# .....
# token: sporting
# Prediction: VBG
# Actual token: NN
# .....
# token: subordinated
# Prediction: VBN
# Actual token: VBD
# .....
# token: increase
# Prediction: NN
# Actual token: VB
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: mid
# Prediction: PRP$
# Actual token: JJ
# .....
# token: ago
# Prediction: IN
# Actual token: RB
# .....
# token: ago
# Prediction: IN
# Actual token: RB
# .....
# token: reached
# Prediction: VBD
# Actual token: VBN
# .....
# token: reduced
# Prediction: JJ
# Actual token: VBN
# .....
# token: trading
# Prediction: NN
# Actual token: VBG
# .....
# token: fixed-income
# Prediction: NN
# Actual token: JJ
# .....
# token: Investment
# Prediction: NNP
# Actual token: NN
# .....
# token: banking
# Prediction: NN
# Actual token: VBG
# .....
# token: Revenue
# Prediction: NNP
# Actual token: NN
# .....
# token: Asset-management
# Prediction: WDT
# Actual token: JJ
# .....
# token: discontinued
# Prediction: JJ
# Actual token: VBN
# .....
# token: Fine
# Prediction: JJ
# Actual token: NNP
# .....
# token: Homes
# Prediction: NNPS
# Actual token: NNP
# .....
# token: net
# Prediction: JJ
# Actual token: NN
# .....
# token: ended
# Prediction: VBD
# Actual token: VBN
# .....
# token: reached
# Prediction: VBN
# Actual token: VBD
# .....
# token: Gross
# Prediction: NNP
# Actual token: JJ
# .....
# token: Profit
# Prediction: NNP
# Actual token: NN
# .....
# token: Investment
# Prediction: NNP
# Actual token: NN
# .....
# token: holding
# Prediction: NN
# Actual token: VBG
# .....
# token: composite
# Prediction: JJ
# Actual token: NN
# .....
# token: Retail
# Prediction: NNP
# Actual token: JJ
# .....
# token: ago
# Prediction: IN
# Actual token: RB
# .....
# token: net
# Prediction: JJ
# Actual token: NN
# .....
# token: banking
# Prediction: NN
# Actual token: VBG
# .....
# token: Rental
# Prediction: JJ
# Actual token: NNP
# .....
# token: Systems
# Prediction: NNPS
# Actual token: NNP
# .....
# token: Revenue
# Prediction: NNP
# Actual token: NN
# .....
# token: composite
# Prediction: JJ
# Actual token: NN
# .....
# token: yesterday
# Prediction: NN
# Actual token: RB
# .....
# token: Seafirst
# Prediction: WDT
# Actual token: NNP
# .....
# token: Selig
# Prediction: POS
# Actual token: NNP
# .....
# token: Seafirst
# Prediction: POS
# Actual token: NNP
# .....
# token: Purchase
# Prediction: NNP
# Actual token: NN
# .....
# token: 76-story
# Prediction: JJS
# Actual token: JJ
# .....
# token: Seafirst
# Prediction: PRP$
# Actual token: NNP
# .....
# token: Individual
# Prediction: NNP
# Actual token: JJ
# .....
# token: dive
# Prediction: NN
# Actual token: VBP
# .....
# token: borrow
# Prediction: VB
# Actual token: VBP
# .....
# token: goosey
# Prediction: NNS
# Actual token: JJ
# .....
# token: hell
# Prediction: NN
# Actual token: UH
# .....
# token: fiddling
# Prediction: JJS
# Actual token: NN
# .....
# token: selling
# Prediction: VBG
# Actual token: NN
# .....
# token: halt
# Prediction: VB
# Actual token: NN
# .....
# token: trading
# Prediction: NN
# Actual token: VBG
# .....
# token: hits
# Prediction: NNS
# Actual token: VBZ
# .....
# token: calm
# Prediction: JJ
# Actual token: VB
# .....
# token: indicated
# Prediction: JJ
# Actual token: VBN
# .....
# token: pre-set
# Prediction: NNS
# Actual token: JJ
# .....
# token: shut
# Prediction: VB
# Actual token: VBD
# .....
# token: about
# Prediction: IN
# Actual token: RB
# .....
# token: Options
# Prediction: NNPS
# Actual token: NNS
# .....
# token: most
# Prediction: JJS
# Actual token: RBS
# .....
# token: less
# Prediction: JJR
# Actual token: RBR
# .....
# token: 3:30
# Prediction: PRP$
# Actual token: CD
# .....
# token: Futures
# Prediction: NNP
# Actual token: NNS
# .....
# token: 3:45
# Prediction: PRP$
# Actual token: CD
# .....
# token: shut
# Prediction: VBN
# Actual token: VBD
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: left
# Prediction: VBN
# Actual token: VBD
# .....
# token: become
# Prediction: VB
# Actual token: VBN
# .....
# token: maximum
# Prediction: JJ
# Actual token: NN
# .....
# token: Synchronized
# Prediction: WDT
# Actual token: VBN
# .....
# token: smoother
# Prediction: JJ
# Actual token: JJR
# .....
# token: less
# Prediction: JJR
# Actual token: RBR
# .....
# token: Securities
# Prediction: NNPS
# Actual token: NNP
# .....
# token: Let
# Prediction: NNP
# Actual token: VB
# .....
# token: 's
# Prediction: POS
# Actual token: PRP
# .....
# token: down
# Prediction: RB
# Actual token: RP
# .....
# token: shut
# Prediction: VBN
# Actual token: VBD
# .....
# token: 250-point
# Prediction: JJS
# Actual token: JJ
# .....
# token: hurried
# Prediction: VBN
# Actual token: JJ
# .....
# token: once
# Prediction: RB
# Actual token: IN
# .....
# token: synchronize
# Prediction: MD
# Actual token: VBP
# .....
# token: continue
# Prediction: VBP
# Actual token: VB
# .....
# token: affected
# Prediction: JJ
# Actual token: VBN
# .....
# token: Commodities
# Prediction: NNS
# Actual token: NNP
# .....
# token: Futures
# Prediction: NNPS
# Actual token: NNP
# .....
# token: stock-index
# Prediction: NN
# Actual token: JJ
# .....
# token: better
# Prediction: JJR
# Actual token: RBR
# .....
# token: today
# Prediction: NN
# Actual token: RB
# .....
# token: Telephone
# Prediction: NNP
# Actual token: NN
# .....
# token: urgings
# Prediction: JJS
# Actual token: NNS
# .....
# token: have
# Prediction: VBP
# Actual token: VB
# .....
# token: Witness
# Prediction: NNP
# Actual token: VB
# .....
# token: early
# Prediction: RB
# Actual token: JJ
# .....
# token: late
# Prediction: RB
# Actual token: JJ
# .....
# token: excess
# Prediction: JJ
# Actual token: NN
# .....
# token: Freund
# Prediction: POS
# Actual token: NNP
# .....
# token: chief
# Prediction: NN
# Actual token: JJ
# .....
# token: UNIFIED
# Prediction: JJS
# Actual token: JJ
# .....
# token: EUROPE
# Prediction: FW
# Actual token: NNP
# .....
# token: European
# Prediction: JJ
# Actual token: NNP
# .....
# token: off
# Prediction: RB
# Actual token: IN
# .....
# token: face
# Prediction: NN
# Actual token: VBP
# .....
# token: like
# Prediction: IN
# Actual token: VB
# .....
# token: relocations
# Prediction: .
# Actual token: NNS
# .....
# token: trained
# Prediction: JJ
# Actual token: VBN
# .....
# token: ease
# Prediction: VB
# Actual token: NN
# .....
# token: CLUBBING
# Prediction: WDT
# Actual token: VBG
# .....
# token: FAN
# Prediction: JJS
# Actual token: NN
# .....
# token: Bluefield
# Prediction: .
# Actual token: NNP
# .....
# token: Martinsville
# Prediction: JJS
# Actual token: NNP
# .....
# token: Phillies
# Prediction: FW
# Actual token: NNP
# .....
# token: that
# Prediction: WDT
# Actual token: DT
# .....
# token: Bluefield
# Prediction: EX
# Actual token: NNP
# .....
# token: Bluefield
# Prediction: EX
# Actual token: NNP
# .....
# token: 9-8
# Prediction: ''
# Actual token: CD
# .....
# token: More
# Prediction: RBR
# Actual token: JJR
# .....
# token: taunting
# Prediction: IN|RB
# Actual token: NN
# .....
# token: kicked
# Prediction: VBD
# Actual token: VBN
# .....
# token: jaw
# Prediction: JJS
# Actual token: NN
# .....
# token: negligent
# Prediction: PRP$
# Actual token: JJ
# .....
# token: PROPOSALS
# Prediction: WDT
# Actual token: NNS
# .....
# token: ARISE
# Prediction: EX
# Actual token: VBP
# .....
# token: Centers
# Prediction: NNPS
# Actual token: NNP
# .....
# token: day-care
# Prediction: JJ
# Actual token: NN
# .....
# token: demanding
# Prediction: VBG
# Actual token: JJ
# .....
# token: American
# Prediction: JJ
# Actual token: NNP
# .....
# token: registered
# Prediction: VBN
# Actual token: JJ
# .....
# token: technologist
# Prediction: .
# Actual token: NN
# .....
# token: bedside
# Prediction: EX
# Actual token: NN
# .....
# token: 618
# Prediction: PRP$
# Actual token: CD
# .....
# token: Hewitt
# Prediction: .
# Actual token: NNP
# .....
# token: Associates
# Prediction: NNPS
# Actual token: NNP
# .....
# token: advancement
# Prediction: RP
# Actual token: NN
# .....
# token: Many
# Prediction: JJ
# Actual token: RB
# .....
# token: MRA
# Prediction: WDT
# Actual token: NNP
# .....
# token: Staffing
# Prediction: EX
# Actual token: NNP
# .....
# token: signs
# Prediction: NNS
# Actual token: VBZ
# .....
# token: up
# Prediction: IN
# Actual token: RP
# .....
# token: subsidized
# Prediction: JJ
# Actual token: VBN
# .....
# token: TREATING
# Prediction: WDT
# Actual token: VBG
# .....
# token: EMPLOYEES
# Prediction: EX
# Actual token: NNS
# .....
# token: Hay
# Prediction: .
# Actual token: NNP
# .....
# token: SPRUCING
# Prediction: WDT
# Actual token: VBG
# .....
# token: UP
# Prediction: IN
# Actual token: RP
# .....
# token: DIGS
# Prediction: JJS
# Actual token: NNS
# .....
# token: painted
# Prediction: VBN
# Actual token: VBD
# .....
# token: polished
# Prediction: VBN
# Actual token: VBD
# .....
# token: carpeted
# Prediction: JJR
# Actual token: VBD
# .....
# token: cleaned
# Prediction: VBN
# Actual token: VBD
# .....
# token: blinds
# Prediction: JJR
# Actual token: NNS
# .....
# token: CURBING
# Prediction: WDT
# Actual token: VBG
# .....
# token: WAGE
# Prediction: EX
# Actual token: NN
# .....
# token: BOOSTS
# Prediction: FW
# Actual token: NNS
# .....
# token: Affairs
# Prediction: NNPS
# Actual token: NNP
# .....
# token: labor-shortage
# Prediction: PRP$
# Actual token: NN
# .....
# token: aim
# Prediction: NN
# Actual token: VBP
# .....
# token: TEMPORARY
# Prediction: WDT
# Actual token: JJ
# .....
# token: WORKERS
# Prediction: NNPS
# Actual token: NNS
# .....
# token: Temporary
# Prediction: PRP$
# Actual token: NNP
# .....
# token: Services
# Prediction: NNPS
# Actual token: NNP
# .....
# token: 2,508
# Prediction: PRP$
# Actual token: CD
# .....
# token: high-school
# Prediction: NN
# Actual token: JJ
# .....
# token: About
# Prediction: IN
# Actual token: RB
# .....
# token: HOME-SALE
# Prediction: WDT
# Actual token: JJ
# .....
# token: LOSSES
# Prediction: EX
# Actual token: NNS
# .....
# token: rise
# Prediction: VB
# Actual token: VBP
# .....
# token: search
# Prediction: VB
# Actual token: VBP
# .....
# token: 439
# Prediction: PRP$
# Actual token: CD
# .....
# token: report
# Prediction: NN
# Actual token: VBP
# .....
# token: About
# Prediction: IN
# Actual token: RB
# .....
# token: reimburse
# Prediction: VB
# Actual token: VBP
# .....
# token: sales-loss
# Prediction: VBN
# Actual token: JJ
# .....
# token: depreciated
# Prediction: VBP
# Actual token: VBD
# .....
# token: up
# Prediction: RB
# Actual token: IN
# .....
# token: posed
# Prediction: VBD
# Actual token: VBN
# .....
# token: prepurchase
# Prediction: RP
# Actual token: JJ
# .....
# token: polled
# Prediction: VBN
# Actual token: VBD
# .....
# token: that
# Prediction: WDT
# Actual token: DT
# .....
# token: reactionary
# Prediction: VBN
# Actual token: JJ
# .....
# token: Carriers
# Prediction: NNPS
# Actual token: NNP
# .....
# token: Sombrotto
# Prediction: POS
# Actual token: NNP
# .....
# token: 88-points
# Prediction: VBN
# Actual token: JJ
# .....
# token: over
# Prediction: IN
# Actual token: RB
# .....
# token: better
# Prediction: JJR
# Actual token: RBR
# .....
# token: know
# Prediction: VBP
# Actual token: VB
# .....
# token: 416.3
# Prediction: JJS
# Actual token: CD
# .....
# token: said
# Prediction: VBN
# Actual token: VBD
# .....
# token: daily
# Prediction: JJ
# Actual token: RB
# .....
# token: devised
# Prediction: VBD
# Actual token: VBN
# .....
# token: falls
# Prediction: VBZ
# Actual token: NNS
# .....
# token: most
# Prediction: JJS
# Actual token: RBS
# .....
# token: as
# Prediction: IN
# Actual token: RB
# .....
# token: rationality
# Prediction: RP
# Actual token: NN
# .....
# token: Chicken
# Prediction: NNP
# Actual token: NN
# .....
# token: Chains
# Prediction: POS
# Actual token: NNS
# .....
# token: Ruffled
# Prediction: FW
# Actual token: VBN
# .....
# token: FAST-FOOD
# Prediction: WDT
# Actual token: NN
# .....
# token: worsening
# Prediction: NN
# Actual token: VBG
# .....
# token: Chicken
# Prediction: NNP
# Actual token: NN
# .....
# token: off
# Prediction: RP
# Actual token: JJ
# .....
# token: grocery-store
# Prediction: PRP$
# Actual token: JJ
# .....
# token: home-delivered
# Prediction: ''
# Actual token: JJ
# .....
# token: takeout
# Prediction: NNS
# Actual token: NN
# .....
# token: fare
# Prediction: VBP
# Actual token: NN
# .....
# token: NPD
# Prediction: PRP$
# Actual token: NNP
# .....
# token: Popeye
# Prediction: JJR
# Actual token: NNP
# .....
# token: troubled
# Prediction: JJ
# Actual token: VBN
# .....
# token: overlapping
# Prediction: VBG
# Actual token: JJ
# .....
# token: Chicken
# Prediction: NNP
# Actual token: NN
# .....
# token: McChicken
# Prediction: JJS
# Actual token: NNP
# .....
# token: tested
# Prediction: VBN
# Actual token: VBD
# .....
# token: New
# Prediction: NNP
# Actual token: JJ
# .....
# token: char-grilled
# Prediction: EX
# Actual token: JJ
# .....
# token: home-delivery
# Prediction: RP
# Actual token: NN
# .....
# token: stay-at-home
# Prediction: PRP$
# Actual token: JJ
# .....
# token: first
# Prediction: JJ
# Actual token: RB
# .....
# token: declines
# Prediction: NNS
# Actual token: VBZ
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: Try
# Prediction: VB
# Actual token: VBP
# .....
# token: Soft-Sell
# Prediction: RP
# Actual token: JJ
# .....
# token: Spots
# Prediction: FW
# Actual token: NNS
# .....
# token: CALL
# Prediction: NNP
# Actual token: VB
# .....
# token: un-advertising
# Prediction: VBP
# Actual token: NN
# .....
# token: yet
# Prediction: RB
# Actual token: CC
# .....
# token: shun
# Prediction: VB
# Actual token: VBP
# .....
# token: Traveler
# Prediction: POS
# Actual token: NNP
# .....
# token: developed
# Prediction: VBD
# Actual token: VBN
# .....
# token: New
# Prediction: NNP
# Actual token: JJ
# .....
# token: un-advertisers
# Prediction: POS
# Actual token: NNS
# .....
# token: Kosar
# Prediction: POS
# Actual token: NNP
# .....
# token: Rittlemann
# Prediction: FW
# Actual token: NNP
# .....
# token: Associates
# Prediction: NNPS
# Actual token: NNP
# .....
# token: features
# Prediction: NNS
# Actual token: VBZ
# .....
# token: Floodlights
# Prediction: EX
# Actual token: NNP
# .....
# token: Evening
# Prediction: ``
# Actual token: NNP
# .....
# token: Wear
# Prediction: VB
# Actual token: NNP
# .....
# token: Structures
# Prediction: POS
# Actual token: NNP
# .....
# token: Building
# Prediction: NNP
# Actual token: VBG
# .....
# token: Park
# Prediction: NNP
# Actual token: VB
# .....
# token: sell
# Prediction: VB
# Actual token: NN
# .....
# token: Kosar
# Prediction: POS
# Actual token: NNP
# .....
# token: detract
# Prediction: EX
# Actual token: VB
# .....
# token: Hospitals
# Prediction: NNPS
# Actual token: NNS
# .....
# token: fundraisers
# Prediction: RP
# Actual token: NNS
# .....
# token: gain
# Prediction: VB
# Actual token: VBP
# .....
# token: Retailer
# Prediction: WDT
# Actual token: NN
# .....
# token: Sees
# Prediction: NNP
# Actual token: VBZ
# .....
# token: Pitfalls
# Prediction: FW
# Actual token: NNS
# .....
# token: Environmental
# Prediction: NNP
# Actual token: JJ
# .....
# token: Push
# Prediction: POS
# Actual token: NN
# .....
# token: Supermarkets
# Prediction: NNS
# Actual token: NNP
# .....
# token: noncorrosive
# Prediction: NNS
# Actual token: JJ
# .....
# token: nonchlorinated
# Prediction: VBN
# Actual token: JJ
# .....
# token: dishwasher
# Prediction: VB
# Actual token: NN
# .....
# token: Sunlight
# Prediction: VBN
# Actual token: NNP
# .....
# token: thrill
# Prediction: VBN
# Actual token: VB
# .....
# token: dishwasher
# Prediction: POS
# Actual token: NN
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: dishwasher
# Prediction: NNS
# Actual token: NN
# .....
# token: Sunlight
# Prediction: JJS
# Actual token: NNP
# .....
# token: Dahlen
# Prediction: POS
# Actual token: NNP
# .....
# token: executive
# Prediction: NN
# Actual token: JJ
# .....
# token: biodegradable
# Prediction: VBN
# Actual token: JJ
# .....
# token: Dahlen
# Prediction: POS
# Actual token: NNP
# .....
# token: philosophically
# Prediction: VBN
# Actual token: RB
# .....
# token: NEATNESS
# Prediction: WDT
# Actual token: NN
# .....
# token: count
# Prediction: NN
# Actual token: VB
# .....
# token: Scanner
# Prediction: JJS
# Actual token: NNP
# .....
# token: dumped
# Prediction: VBN
# Actual token: VBD
# .....
# token: endorsers
# Prediction: VB
# Actual token: NNS
# ...
# Prediction: JJS
# Actual token: JJ
# .....
# token: ballet
# Prediction: PRP$
# Actual token: NN
# .....
# token: her
# Prediction: PRP$
# Actual token: PRP
# .....
# token: enchanting
# Prediction: VBP
# Actual token: JJ
# .....
# token: 1910
# Prediction: JJS
# Actual token: CD
# .....
# token: Kchessinska
# Prediction: VBN
# Actual token: NNP
# .....
# token: reclining
# Prediction: VB
# Actual token: VBG
# .....
# token: chaise
# Prediction: JJS
# Actual token: NN
# .....
# token: longue
# Prediction: FW
# Actual token: NN
# .....
# token: balcony
# Prediction: JJS
# Actual token: NN
# .....
# token: Lenin
# Prediction: MD
# Actual token: NNP
# .....
# token: Revolution
# Prediction: NNP
# Actual token: NN
# .....
# token: Diaghilev
# Prediction: JJS
# Actual token: NNP
# .....
# token: less
# Prediction: JJR
# Actual token: RBR
# .....
# token: Ballets
# Prediction: JJS
# Actual token: NNP
# .....
# token: Russes
# Prediction: FW
# Actual token: NNP
# .....
# token: most
# Prediction: RBS
# Actual token: JJS
# .....
# token: West
# Prediction: JJ
# Actual token: NN
# .....
# token: Balanchine
# Prediction: POS
# Actual token: NNP
# .....
# token: Geva
# Prediction: POS
# Actual token: NNP
# .....
# token: teenager
# Prediction: JJS
# Actual token: NN
# .....
# token: 1923
# Prediction: PRP$
# Actual token: CD
# .....
# token: Better
# Prediction: NNP
# Actual token: RB
# .....
# token: accorded
# Prediction: VBN
# Actual token: VBD
# .....
# token: avant-garde
# Prediction: JJS
# Actual token: JJ
# .....
# token: flourished
# Prediction: MD
# Actual token: VBD
# .....
# token: ruthlessly
# Prediction: PRP$
# Actual token: RB
# .....
# token: repressed
# Prediction: CD
# Actual token: VBN
# .....
# token: much
# Prediction: RB
# Actual token: JJ
# .....
# token: Feodor
# Prediction: RP
# Actual token: NNP
# .....
# token: Lopukhov
# Prediction: VB
# Actual token: NNP
# .....
# token: leading
# Prediction: JJ
# Actual token: VBG
# .....
# token: choreographer
# Prediction: NNS
# Actual token: NN
# .....
# token: post-Revolutionary
# Prediction: JJS
# Actual token: JJ
# .....
# token: welcome
# Prediction: VB
# Actual token: JJ
# .....
# token: Less
# Prediction: RBR
# Actual token: JJR
# .....
# token: welcome
# Prediction: JJ
# Actual token: NN
# .....
# token: indisputable
# Prediction: JJS
# Actual token: JJ
# .....
# token: Miscellaneous
# Prediction: WDT
# Actual token: JJ
# .....
# token: haphazard
# Prediction: JJR
# Actual token: JJ
# .....
# token: need
# Prediction: VBP
# Actual token: VB
# .....
# token: Pavlova
# Prediction: POS
# Actual token: NNP
# .....
# token: set
# Prediction: VBD
# Actual token: NN
# .....
# token: Petipa
# Prediction: POS
# Actual token: NNP
# .....
# token: slipper
# Prediction: JJS
# Actual token: NN
# .....
# token: viewing
# Prediction: VBG
# Actual token: NN
# .....
# token: Nakhamkin
# Prediction: JJS
# Actual token: NNP
# .....
# token: come
# Prediction: VB
# Actual token: VBN
# .....
# token: ballet
# Prediction: VBN
# Actual token: NN
# .....
# token: 1830
# Prediction: PRP$
# Actual token: CD
# .....
# token: well-illustrated
# Prediction: PRP$
# Actual token: JJ
# .....
# token: Saratoga
# Prediction: PRP$
# Actual token: NNP
# .....
# token: Dance
# Prediction: NN
# Actual token: NNP
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: one
# Prediction: PRP
# Actual token: CD
# .....
# token: add
# Prediction: VB
# Actual token: VBP
# .....
# token: up
# Prediction: RP
# Actual token: IN
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: mathematics
# Prediction: NN
# Actual token: NNS
# .....
# token: French-government-owned
# Prediction: JJS
# Actual token: JJ
# .....
# token: earlier
# Prediction: RB
# Actual token: RBR
# .....
# token: as
# Prediction: IN
# Actual token: RB
# .....
# token: data-processing
# Prediction: NN
# Actual token: JJ
# .....
# token: Merger
# Prediction: NNP
# Actual token: NN
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: 537
# Prediction: PRP$
# Actual token: CD
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: black
# Prediction: JJ
# Actual token: NN
# .....
# token: as
# Prediction: IN
# Actual token: RB
# .....
# token: Angers
# Prediction: JJS
# Actual token: NNP
# .....
# token: had
# Prediction: VBD
# Actual token: VBN
# .....
# token: 31.55
# Prediction: PRP$
# Actual token: CD
# .....
# token: key
# Prediction: JJ
# Actual token: NN
# .....
# token: 69.4
# Prediction: VB
# Actual token: CD
# .....
# token: controlling
# Prediction: JJ
# Actual token: VBG
# .....
# token: HN
# Prediction: POS
# Actual token: NNP
# .....
# token: HN
# Prediction: POS
# Actual token: NNP
# .....
# token: reports
# Prediction: NNS
# Actual token: VBZ
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: Machines
# Prediction: NNPS
# Actual token: NNP
# .....
# token: all
# Prediction: DT
# Actual token: PDT
# .....
# token: externally
# Prediction: PRP$
# Actual token: RB
# .....
# token: breakneck
# Prediction: PRP$
# Actual token: JJ
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: firm
# Prediction: NN
# Actual token: JJ
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: half-dozen
# Prediction: JJ
# Actual token: NN
# .....
# token: full-range
# Prediction: ''
# Actual token: JJ
# .....
# token: 1990s
# Prediction: NNS
# Actual token: CD
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: buy
# Prediction: VB
# Actual token: NN
# .....
# token: up
# Prediction: RB
# Actual token: IN
# .....
# token: billion-franc
# Prediction: CD
# Actual token: NN
# .....
# token: Keeping
# Prediction: VBG
# Actual token: NNP
# .....
# token: independant
# Prediction: VBN
# Actual token: JJ
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: disarmingly
# Prediction: VBN
# Actual token: RB
# .....
# token: PC
# Prediction: NN
# Actual token: NNP
# .....
# token: get
# Prediction: VB
# Actual token: VBP
# .....
# token: originality
# Prediction: JJS
# Actual token: NN
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: vocation
# Prediction: JJS
# Actual token: NN
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: ago
# Prediction: RB
# Actual token: IN
# .....
# token: chief
# Prediction: JJ
# Actual token: NN
# .....
# token: French
# Prediction: JJ
# Actual token: NNP
# .....
# token: automated-teller
# Prediction: JJ
# Actual token: NN
# .....
# token: front-desk
# Prediction: JJS
# Actual token: NN
# .....
# token: back-office
# Prediction: JJ
# Actual token: NN
# .....
# token: all
# Prediction: DT
# Actual token: PDT
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: succeeded
# Prediction: VBN
# Actual token: VBD
# .....
# token: crusader
# Prediction: JJS
# Actual token: NN
# .....
# token: that
# Prediction: WDT
# Actual token: DT
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: inherits
# Prediction: ''
# Actual token: VBZ
# .....
# token: healthiest
# Prediction: JJR
# Actual token: JJS
# .....
# token: soup-to-nuts
# Prediction: NNS
# Actual token: JJ
# .....
# token: likes
# Prediction: VBZ
# Actual token: NNS
# .....
# token: only
# Prediction: RB
# Actual token: JJ
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: cerebral
# Prediction: ''
# Actual token: JJ
# .....
# token: Ecole
# Prediction: EX
# Actual token: NNP
# .....
# token: d'Administration
# Prediction: POS
# Actual token: NNP
# .....
# token: used
# Prediction: VBN
# Actual token: VBD
# .....
# token: aikido
# Prediction: PRP$
# Actual token: FW
# .....
# token: asked
# Prediction: VBN
# Actual token: VBD
# .....
# token: unfocussed
# Prediction: JJS
# Actual token: VBN
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: banalization
# Prediction: NNS
# Actual token: NN
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: future
# Prediction: JJ
# Actual token: NN
# .....
# token: all
# Prediction: DT
# Actual token: PDT
# .....
# token: PCs
# Prediction: NNS
# Actual token: NNP
# .....
# token: stable
# Prediction: JJ
# Actual token: NN
# .....
# token: Lorentz
# Prediction: POS
# Actual token: NNP
# .....
# token: better
# Prediction: JJR
# Actual token: RB
# .....
# token: armed
# Prediction: JJ
# Actual token: VBN
# .....
# token: Lorenz
# Prediction: POS
# Actual token: NNP
# .....
# token: so
# Prediction: RB
# Actual token: IN
# .....
# token: so
# Prediction: RB
# Actual token: IN
# .....
# token: splits
# Prediction: VBZ
# Actual token: NNS
# .....
# token: all
# Prediction: DT
# Actual token: PDT
# .....
# token: splits
# Prediction: VBZ
# Actual token: NNS
# .....
# token: unaccompanied
# Prediction: .
# Actual token: JJ
# .....
# token: singles
# Prediction: CD
# Actual token: NNS
# .....
# token: billfold
# Prediction: IN
# Actual token: NN
# .....
# token: Cooperman
# Prediction: POS
# Actual token: NNP
# .....
# token: increases
# Prediction: NNS
# Actual token: VBZ
# .....
# token: split
# Prediction: VBN
# Actual token: VBD
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: increase
# Prediction: NN
# Actual token: VB
# .....
# token: selling
# Prediction: NN
# Actual token: VBG
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: selling
# Prediction: NN
# Actual token: VBG
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: round
# Prediction: NN
# Actual token: JJ
# .....
# token: Horowitz
# Prediction: POS
# Actual token: NNP
# .....
# token: executive
# Prediction: NN
# Actual token: JJ
# .....
# token: chief
# Prediction: JJ
# Actual token: NN
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: that
# Prediction: IN
# Actual token: WDT
# .....
# token: boost
# Prediction: NN
# Actual token: VBP
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
# token: Horowitz
# Prediction: POS
# Actual token: NNP
# .....
# token: that
# Prediction: IN
# Actual token: RB
# .....
# token: Investment
# Prediction: NNP
# Actual token: NN
# .....
# token: lasting
# Prediction: JJ
# Actual token: VBG
# .....
# token: Cooperman
# Prediction: POS
# Actual token: NNP
# .....
# token: Cochrane
# Prediction: POS
# Actual token: NNP
# .....
# token: have
# Prediction: VB
# Actual token: VBP
# .....
# token: adage
# Prediction: POS
# Actual token: NN
# .....
# token: Thorne
# Prediction: POS
# Actual token: NNP
# .....
# token: managing
# Prediction: NN
# Actual token: VBG
# .....
# token: Scudder
# Prediction: PRP$
# Actual token: NNP
# .....
# token: Splits
# Prediction: WDT
# Actual token: NNS
# .....
# token: sell
# Prediction: VB
# Actual token: VBP
# .....
# token: calculate
# Prediction: VB
# Actual token: VBP
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: about
# Prediction: RB
# Actual token: IN
# .....
# token: Stock
# Prediction: NNP
# Actual token: NN
# .....
# token: splits
# Prediction: VBZ
# Actual token: NNS
# .....
# token: ripoff
# Prediction: NNS
# Actual token: NN
# .....
# token: Reinisch
# Prediction: POS
# Actual token: NNP
# .....
# token: that
# Prediction: IN
# Actual token: WDT
# .....
# token: changes
# Prediction: NNS
# Actual token: VBZ
# .....
# token: go
# Prediction: VB
# Actual token: VBP
# .....
# token: up
# Prediction: RP
# Actual token: IN
# .....
# token: chief
# Prediction: JJ
# Actual token: NN
# .....
# token: executive
# Prediction: NN
# Actual token: JJ
# .....
# token: pro-shareholder
# Prediction: JJS
# Actual token: NN
# .....
# token: followed
# Prediction: VBN
# Actual token: VBD
# .....
# token: focused
# Prediction: VBD
# Actual token: VBN
# .....
# token: subject
# Prediction: JJ
# Actual token: NN
# .....
# token: sent
# Prediction: VBN
# Actual token: VBD
# .....
# token: greeting
# Prediction: VBG
# Actual token: NN
# .....
# token: May
# Prediction: NNP
# Actual token: MD
# .....
# token: live
# Prediction: VBP
# Actual token: VB
# .....
# token: like
# Prediction: IN
# Actual token: VBP
# .....
# token: that
# Prediction: IN
# Actual token: DT
# .....
# token: about
# Prediction: RB
# Actual token: IN
# .....
# token: net
# Prediction: JJ
# Actual token: NN
# .....
# token: Silberberg
# Prediction: PRP$
# Actual token: NNP
# .....
# token: Advises
# Prediction: WDT
# Actual token: VBZ
# .....
# token: Metz
# Prediction: POS
# Actual token: NNP
# .....
# token: managing
# Prediction: NN
# Actual token: VBG
# .....
# token: underwiters
# Prediction: PRP$
# Actual token: NNS
# .....
# token: led
# Prediction: VBD
# Actual token: VBN
# .....
# token: Scotia-McLeod
# Prediction: PRP$
# Actual token: NNP
# .....
# token: principal
# Prediction: NN
# Actual token: JJ
# .....
# token: subordinated
# Prediction: JJ
# Actual token: VBN
# .....
# token: diversified
# Prediction: JJ
# Actual token: VBN
# .....
# token: Class
# Prediction: NN
# Actual token: NNP
# .....
# token: A
# Prediction: DT
# Actual token: NNP
# .....
# token: reported
# Prediction: VBD
# Actual token: VBN
# .....
# token: W.H.
# Prediction: RP
# Actual token: NNP
# .....
# token: destroyer
# Prediction: JJS
# Actual token: NN
# .....
# token: DDG-51
# Prediction: FW
# Actual token: NNP
# .....
# token: Arleigh
# Prediction: JJS
# Actual token: NNP
# .....
# token: aluminum-hulled
# Prediction: NNS
# Actual token: JJ
# .....
# token: aluminum-hulled
# Prediction: CD
# Actual token: JJ
# .....
# token: Exocet
# Prediction: JJS
# Actual token: NNP
# .....
# token: off
# Prediction: RP
# Actual token: IN
# .....
# token: ignited
# Prediction: MD
# Actual token: VBD
# .....
# token: superstructure
# Prediction: .
# Actual token: NN
# .....
# token: As
# Prediction: IN
# Actual token: RB
# .....
# token: such
# Prediction: JJ
# Actual token: PDT
# .....
# token: sensibly
# Prediction: VBN
# Actual token: RB
# .....
# token: aluminum
# Prediction: NN
# Actual token: JJ
# .....
# token: Aegis-class
# Prediction: .
# Actual token: JJ
# .....
# token: Snoozing
# Prediction: EX
# Actual token: VBG
# .....
# token: Adi
# Prediction: .
# Actual token: NNP
# .....
# token: Diary
# Prediction: POS
# Actual token: NNP
# .....
# token: Thirteen
# Prediction: ``
# Actual token: CD
# .....
# token: Days
# Prediction: NNS
# Actual token: NNPS
# .....
# token: Leisire
# Prediction: $
# Actual token: NNP
# .....
# token: terror
# Prediction: JJR
# Actual token: NN
# .....
# token: mistake
# Prediction: NN
# Actual token: VB
# .....
# token: rough-cut
# Prediction: ''
# Actual token: JJ
# .....
# token: unretouched
# Prediction: ''
# Actual token: JJ
# .....
# token: diary
# Prediction: NNS
# Actual token: NN
# .....
# token: lice
# Prediction: .
# Actual token: NNS
# .....
# token: all
# Prediction: DT
# Actual token: PDT
# .....
# token: confusions
# Prediction: JJS
# Actual token: NNS
# .....
# token: high-gloss
# Prediction: PRP$
# Actual token: JJ
# .....
# token: footnoted
# Prediction: CD
# Actual token: VBN
# .....
# token: insta-book
# Prediction: EX
# Actual token: NN
# .....
# token: Taconic
# Prediction: WDT
# Actual token: NNP
# .....
# token: REPLIGEN
# Prediction: WDT
# Actual token: NNP
# .....
# token: manufacturing
# Prediction: VBG
# Actual token: NN
# .....
# token: Repligen
# Prediction: ''
# Actual token: NNP
# .....
# token: Repligen
# Prediction: ''
# Actual token: NNP
# .....
# token: In
# Prediction: IN
# Actual token: NNP
# .....
# token: Other
# Prediction: JJ
# Actual token: NNP
# .....
# token: Words
# Prediction: NNS
# Actual token: NNPS
# .....
# token: Must
# Prediction: WDT
# Actual token: MD
# .....
# token: Beady
# Prediction: EX
# Actual token: JJ
# .....
# token: vexing
# Prediction: VBN
# Actual token: JJ
# .....
# token: flexing
# Prediction: EX
# Actual token: VBG
# .....
# token: Happened
# Prediction: WDT
# Actual token: VBN
# .....
# token: synonyms
# Prediction: VB
# Actual token: NNS
# .....
# token: Numbers
# Prediction: PRP$
# Actual token: NNPS
# .....
# token: raison
# Prediction: EX
# Actual token: FW
# .....
# token: construe
# Prediction: VB
# Actual token: VBP
# .....
# token: mess
# Prediction: NN
# Actual token: VB
# .....
# token: Horseman
# Prediction: WDT
# Actual token: NN
# .....
# token: reinman
# Prediction: ``
# Actual token: NN
# .....
# token: proposed
# Prediction: JJ
# Actual token: VBN
# .....
# token: held
# Prediction: VBD
# Actual token: VBN
# .....
# token: Securities
# Prediction: NNP
# Actual token: NNS
# .....
# token: kitchen-sink
# Prediction: EX
# Actual token: JJ
# .....
# token: coming
# Prediction: JJ
# Actual token: VBG
# .....
# token: loan-loss
# Prediction: JJ
# Actual token: NN
# .....
# token: troubled
# Prediction: JJ
# Actual token: VBN
# .....
# token: Latin
# Prediction: NNP
# Actual token: JJ
# .....
# token: American
# Prediction: NNP
# Actual token: JJ
# .....
# token: soured
# Prediction: VBD
# Actual token: VBN
# .....
# token: coming
# Prediction: JJ
# Actual token: VBG
# .....
# token: future
# Prediction: JJ
# Actual token: NN
# .....
# token: Manufacturers
# Prediction: NNP
# Actual token: NNPS
# .....
# token: all
# Prediction: DT
# Actual token: PDT
# .....
# token: use
# Prediction: NN
# Actual token: VB
# .....
# token: reserve-building
# Prediction: PRP$
# Actual token: NN
# .....
# token: up
# Prediction: RP
# Actual token: IN
# .....
# token: Manufacturers
# Prediction: NNP
# Actual token: NNPS
# .....
# token: third-quarter
# Prediction: JJ
# Actual token: NN
# .....
# token: continued
# Prediction: JJ
# Actual token: VBN
# .....
# token: third-quarter
# Prediction: JJ
# Actual token: NN
# .....
# token: narrowing
# Prediction: NN
# Actual token: VBG
# .....
# token: 4.39
# Prediction: VB
# Actual token: CD
# .....
# token: Further
# Prediction: RB
# Actual token: JJ
# .....
# token: Nonperforming
# Prediction: JJ
# Actual token: VBG
# .....
# token: Resorts
# Prediction: NNP
# Actual token: NNPS
# .....
# token: more
# Prediction: JJR
# Actual token: RBR
# .....
